# %% [markdown]
# # Imports and data loading

# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %% [markdown]
# ### Imports

# %%
exec(open("props.py"))
exec(open("helpers.py"))
from __future__ import division
output_notebook(); #force plots to display inline
# %matplotlib inline
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="63be71c8-dbaf-431f-b9b1-7445b50d09b7">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ### Load data (only do once and then proceed with analysis!)

# %%
# make sure we are using an updated copy of the file, since jupyter tends to cache notebooks
# %load_ext autoreload
# %autoreload loadData

# takes about 4 mins
# %run loadData.ipynb
# Out:
# There are
# 884
# fake ages
#
# There are
# 192432
# previously unknown ages
#
# Total unknown ages is
# 193316
# out of
# 1731594
# total ages
# for percentage
# 0
# There are
# 0
# fake ages
#
# There are
# 193316
# unknown ages
#
# Total unknown ages is
# 193316
# out of
# 1731594
# total ages
# for percentage
# 0

# %% [markdown]
# # Geographic analysis plots

# %% [markdown]
# ### Generic names so I can refactor here instead of refactoring in each plot

# %%
data = Jun17
month = "June"
numDaysMonth = 30

# %% [markdown]
# ### We'll look for the most frequent stations by their id, then print out the plaintext names for easy identification on a map
#
# This was put onto a google map with pins for START,END,BOTH locations
# https://drive.google.com/open?id=1FCjRkk30qxZ7S7p_1iCFA480_JduYe5i&usp=sharing

# %%
print 'START STATION ID'
print data.startstationid.value_counts(sort=True, dropna=False)
topstart = data.startstationid.value_counts(sort=True, dropna=False)[0:20].index
print 'END STATION ID'
print data.endstationid.value_counts(sort=True, dropna=False)
topend = data.endstationid.value_counts(sort=True, dropna=False)[0:20].index
# print 'START STATION NAME'
# print data.startstationname
# print 'END STATION NAME'
# print data.endstationname
# Out:
# START STATION ID
# 519     16364
# 426     13542
# 497     11703
# 402     11388
# 514     11301
# 435     10889
# 459     10574
# 3255    10497
# 490     10009
# 368      9142
# 281      8981
# 523      8976
# 3002     8968
# 477      8964
# 2006     8403
# 284      8298
# 285      8268
# 151      8063
# 168      8050
# 3263     8048
# 358      7803
# 293      7735
# 382      7700
# 359      7690
# 229      7557
# 379      7549
# 128      7532
# 505      7488
# 444      7445
# 492      7282
#         ...
# 3063      350
# 3127      344
# 3061      327
# 3302      308
# 3044      306
# 119       303
# 3327      295
# 3342      274
# 3456      267
# 2005      264
# 3075      262
# 3352      259
# 3337      250
# 3395      199
# 3340      195
# 3326      178
# 3245      171
# 3394      156
# 3330      139
# 3333      131
# 3257       69
# 3432       59
# 3468       32
# 3474       28
# 3250        6
# 3470        5
# 3036        4
# 3239        4
# 3248        2
# 3040        1
# Name: startstationid, dtype: int64
# END STATION ID
# 519     16089
# 426     14122
# 402     12006
# 497     11991
# 514     11272
# 459     11092
# 435     10993
# 3255    10645
# 368      9314
# 490      9213
# 523      9026
# 3002     9001
# 284      8365
# 168      8297
# 285      8256
# 477      8196
# 151      8084
# 432      8072
# 2006     8070
# 358      8005
# 359      7923
# 382      7721
# 293      7721
# 229      7624
# 128      7543
# 505      7496
# 444      7468
# 3263     7394
# 212      7225
# 281      7176
#         ...
# 3456      259
# 3075      243
# 3340      228
# 3432      218
# 3395      204
# 3326      201
# 3333      185
# 3245      183
# 3394      172
# 3330      163
# 3257       58
# 3468       34
# 3250       32
# 3474       27
# 3267        8
# 3470        5
# 3240        5
# 3184        5
# 3036        4
# 3253        4
# 3239        4
# 3248        3
# 3214        3
# 3186        3
# 3213        2
# 3273        2
# 3183        2
# 3202        1
# 3040        1
# 3185        1
# Name: endstationid, dtype: int64

# %%
print 'START'
topstartnames = []
for idx,elem in enumerate(topstart):
    print str(idx+1)+")"+data[data.startstationid==elem].startstationname.unique()
    topstartnames.append(data[data.startstationid==elem].startstationname.unique()[0])
print idx
# Out:
# START
# ['1)Pershing Square North']
# ['2)West St & Chambers St']
# ['3)E 17 St & Broadway']
# ['4)Broadway & E 22 St']
# ['5)12 Ave & W 40 St']
# ['6)W 21 St & 6 Ave']
# ['7)W 20 St & 11 Ave']
# ['8)8 Ave & W 31 St']
# ['9)8 Ave & W 33 St']
# ['10)Carmine St & 6 Ave']
# ['11)Grand Army Plaza & Central Park S']
# ['12)W 38 St & 8 Ave']
# ['13)South End Ave & Liberty St']
# ['14)W 41 St & 8 Ave']
# ['15)Central Park S & 6 Ave']
# ['16)Greenwich Ave & 8 Ave']
# ['17)Broadway & E 14 St']
# ['18)Cleveland Pl & Spring St']
# ['19)W 18 St & 6 Ave']
# ['20)Cooper Square & E 7 St']
# 19

# %%
print 'END'
topendnames = []
for idx,elem in enumerate(topend):
    print str(idx+1)+")"+data[data.endstationid==elem].endstationname.unique()
    topendnames.append(data[data.endstationid==elem].endstationname.unique()[0])
print idx
# Out:
# END
# ['1)Pershing Square North']
# ['2)West St & Chambers St']
# ['3)Broadway & E 22 St']
# ['4)E 17 St & Broadway']
# ['5)12 Ave & W 40 St']
# ['6)W 20 St & 11 Ave']
# ['7)W 21 St & 6 Ave']
# ['8)8 Ave & W 31 St']
# ['9)Carmine St & 6 Ave']
# ['10)8 Ave & W 33 St']
# ['11)W 38 St & 8 Ave']
# ['12)South End Ave & Liberty St']
# ['13)Greenwich Ave & 8 Ave']
# ['14)W 18 St & 6 Ave']
# ['15)Broadway & E 14 St']
# ['16)W 41 St & 8 Ave']
# ['17)Cleveland Pl & Spring St']
# ['18)E 7 St & Avenue A']
# ['19)Central Park S & 6 Ave']
# ['20)Christopher St & Greenwich St']
# 19

# %%
print 'BOTH'
overlap = np.intersect1d(topstart,topend)
print overlap.size
for idx,elem in enumerate(overlap):
    print data[data.endstationid==elem].endstationname.unique()
    print data[data.startstationid==elem].startstationname.unique()
print idx
# Out:
# BOTH
# 18
# ['Cleveland Pl & Spring St']
# ['Cleveland Pl & Spring St']
# ['W 18 St & 6 Ave']
# ['W 18 St & 6 Ave']
# ['Greenwich Ave & 8 Ave']
# ['Greenwich Ave & 8 Ave']
# ['Broadway & E 14 St']
# ['Broadway & E 14 St']
# ['Carmine St & 6 Ave']
# ['Carmine St & 6 Ave']
# ['Broadway & E 22 St']
# ['Broadway & E 22 St']
# ['West St & Chambers St']
# ['West St & Chambers St']
# ['W 21 St & 6 Ave']
# ['W 21 St & 6 Ave']
# ['W 20 St & 11 Ave']
# ['W 20 St & 11 Ave']
# ['W 41 St & 8 Ave']
# ['W 41 St & 8 Ave']
# ['8 Ave & W 33 St']
# ['8 Ave & W 33 St']
# ['E 17 St & Broadway']
# ['E 17 St & Broadway']
# ['12 Ave & W 40 St']
# ['12 Ave & W 40 St']
# ['Pershing Square North']
# ['Pershing Square North']
# ['W 38 St & 8 Ave']
# ['W 38 St & 8 Ave']
# ['Central Park S & 6 Ave']
# ['Central Park S & 6 Ave']
# ['South End Ave & Liberty St']
# ['South End Ave & Liberty St']
# ['8 Ave & W 31 St']
# ['8 Ave & W 31 St']
# 17

# %% [markdown]
# ### Start stations histogram

# %%
p = figure(x_range = topstartnames)
standardize(p)
standardizevbar(p)

x=topstartnames
temp = data[data.startstationid.isin(topstart)]
temp = temp.groupby('startstationid').count().max(1).values
temp = np.sort(temp)
temp = temp[::-1] # to sort in descending order
top = temp
width = 0.85
bottom = 0
p.vbar(x=x,top=top,width=width,bottom=bottom,color='skyblue');

pcts = top/data.shape[0]*100
pcts = np.round(pcts,2)
pctsStrings = []
for i in range(pcts.size):
    pctsStrings.append(str(pcts[i]) + "%")
source = ColumnDataSource(data=dict(x=x,
                                   top=top,
                                   pcts=pctsStrings))
labels = LabelSet(x='x',y='top',text='pcts',
                 level='glyph',x_offset=0,y_offset=5,
                 source=source,render_mode='canvas',
                 text_align='center',text_font_size='7pt',angle=-0.5)
p.add_layout(labels)
print(str(sum(pcts)) + '% of trips originated at these stations')

p.title.text = 'Trips Taken From Top 20 Origin Stations'
p.xaxis.axis_label = 'Station Name'
p.yaxis.axis_label = '# of trips'

p.left[0].formatter.use_scientific = False
# Out:
# 11.6% of trips originated at these stations

# %%
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="98ed36c0-d457-4c60-b569-13d5df621cd2"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("98ed36c0-d457-4c60-b569-13d5df621cd2");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("98ed36c0-d457-4c60-b569-13d5df621cd2");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '98ed36c0-d457-4c60-b569-13d5df621cd2' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"e0c7c579-2c10-4e29-b89c-671c377daf2e":{"roots":{"references":[{"attributes":{"callback":null,"start":0},"id":"2268633f-81fb-4f82-bc1d-244216ecf09c","type":"DataRange1d"},{"attributes":{"angle":{"units":"rad","value":-0.5},"level":"glyph","plot":{"id":"49a48925-aa60-45ee-b1e7-3de5063f0843","subtype":"Figure","type":"Plot"},"source":{"id":"00e29043-9595-434c-a0b0-697e644e3612","type":"ColumnDataSource"},"text":{"field":"pcts"},"text_align":"center","text_font_size":{"value":"7pt"},"x":{"field":"x"},"y":{"field":"top"},"y_offset":{"value":5}},"id":"cd973a61-fac4-442c-a3f3-75760d75f3cf","type":"LabelSet"},{"attributes":{},"id":"f05ae18b-7f21-4fbe-8fba-70b6c73f542f","type":"LinearScale"},{"attributes":{},"id":"8b07fc6d-c878-4bc9-aa5c-cb216dfb6521","type":"BasicTicker"},{"attributes":{"axis_label":"Station Name","axis_label_text_font_size":{"value":"14pt"},"formatter":{"id":"dcf6548f-f888-4578-b399-20cc7a37a936","type":"CategoricalTickFormatter"},"major_label_orientation":-0.75,"major_label_text_font_size":{"value":"9pt"},"minor_tick_line_color":{"value":null},"plot":{"id":"49a48925-aa60-45ee-b1e7-3de5063f0843","subtype":"Figure","type":"Plot"},"ticker":{"id":"3b9838b3-83ec-4e67-bb61-3087869b7721","type":"CategoricalTicker"}},"id":"0d80cc2c-226f-488a-822c-e0852d5cf435","type":"CategoricalAxis"},{"attributes":{},"id":"7c6c501f-4e2d-4cd3-9769-8f8cf3523169","type":"HelpTool"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"1bf84d72-4d60-4910-b4ef-a6f5c965068a","type":"PanTool"},{"id":"9741a599-884b-4530-80ea-d98c05da3db6","type":"WheelZoomTool"},{"id":"f4633be4-6b8d-4f24-8830-d2d11a7a6bad","type":"BoxZoomTool"},{"id":"ff93ebe3-8019-4682-8383-da5ed5ec2145","type":"SaveTool"},{"id":"9efe18f8-bfef-48f8-a9a4-99f062ce4c66","type":"ResetTool"},{"id":"7c6c501f-4e2d-4cd3-9769-8f8cf3523169","type":"HelpTool"}]},"id":"8b71a8ac-e43f-4d47-99ca-ca030ec005b0","type":"Toolbar"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"1d5373d6-2eda-41d6-a9bd-415bd80b960c","type":"BoxAnnotation"},{"attributes":{"grid_line_color":{"value":null},"plot":{"id":"49a48925-aa60-45ee-b1e7-3de5063f0843","subtype":"Figure","type":"Plot"},"ticker":{"id":"3b9838b3-83ec-4e67-bb61-3087869b7721","type":"CategoricalTicker"}},"id":"78b58cf0-e25c-41c6-a39c-876f936e249f","type":"Grid"},{"attributes":{},"id":"c6fe8d25-2079-4d0b-8e16-e2405a11e26d","type":"CategoricalScale"},{"attributes":{"overlay":{"id":"1d5373d6-2eda-41d6-a9bd-415bd80b960c","type":"BoxAnnotation"}},"id":"f4633be4-6b8d-4f24-8830-d2d11a7a6bad","type":"BoxZoomTool"},{"attributes":{"align":"center","plot":null,"text":"Trips Taken From Top 20 Origin Stations","text_font_size":{"value":"16pt"}},"id":"419a218d-3157-40c8-8726-34ea46ced9cd","type":"Title"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"top":{"field":"top"},"width":{"value":0.85},"x":{"field":"x"}},"id":"96d90dbe-0f2d-4015-ba6a-ac5c6cbe6040","type":"VBar"},{"attributes":{},"id":"9741a599-884b-4530-80ea-d98c05da3db6","type":"WheelZoomTool"},{"attributes":{"dimension":1,"plot":{"id":"49a48925-aa60-45ee-b1e7-3de5063f0843","subtype":"Figure","type":"Plot"},"ticker":{"id":"8b07fc6d-c878-4bc9-aa5c-cb216dfb6521","type":"BasicTicker"}},"id":"a8688f05-b926-4e57-806b-4c14458f4670","type":"Grid"},{"attributes":{"use_scientific":false},"id":"f3bf66b7-db36-44be-8840-30e0aa282f7b","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["pcts","x","top"],"data":{"pcts":["0.95%","0.78%","0.68%","0.66%","0.65%","0.63%","0.61%","0.61%","0.58%","0.53%","0.52%","0.52%","0.52%","0.52%","0.49%","0.48 ...

# %% [markdown]
# ### End stations histogram

# %%
p = figure(x_range = topendnames)
standardize(p)
standardizevbar(p)

x=topendnames
temp = data[data.endstationid.isin(topend)]
temp = temp.groupby('endstationid').count().max(1).values
temp = np.sort(temp)
temp = temp[::-1] # to sort in descending order
top = temp
width = 0.85
bottom = 0
p.vbar(x=x,top=top,width=width,bottom=bottom,color='skyblue');

pcts = top/data.shape[0]*100
pcts = np.round(pcts,2)
pctsStrings = []
for i in range(pcts.size):
    pctsStrings.append(str(pcts[i]) + "%")
source = ColumnDataSource(data=dict(x=x,
                                   top=top,
                                   pcts=pctsStrings))
labels = LabelSet(x='x',y='top',text='pcts',
                 level='glyph',x_offset=0,y_offset=5,
                 source=source,render_mode='canvas',
                 text_align='center',text_font_size='7pt',angle=-0.5)
p.add_layout(labels)
print(str(sum(pcts))+ '% of trips ended at these stations')

p.title.text = 'Trips Taken From Top 20 Destination Stations'
p.xaxis.axis_label = 'Station Name'
p.yaxis.axis_label = '# of trips'

p.left[0].formatter.use_scientific = False
# Out:
# 11.55% of trips ended at these stations

# %%
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="3f548d21-bb28-4a20-9101-c1dd2c2b8c43"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("3f548d21-bb28-4a20-9101-c1dd2c2b8c43");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("3f548d21-bb28-4a20-9101-c1dd2c2b8c43");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '3f548d21-bb28-4a20-9101-c1dd2c2b8c43' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"2c7cdd52-af67-4d32-b110-3fffc66a9f27":{"roots":{"references":[{"attributes":{},"id":"eeccad04-3830-4ad4-b5e0-8b68b0ad64f4","type":"ResetTool"},{"attributes":{},"id":"404e9272-66e1-4b05-8a03-1dddeee8f1fa","type":"SaveTool"},{"attributes":{"axis_label":"Station Name","axis_label_text_font_size":{"value":"14pt"},"formatter":{"id":"f058405a-f7e1-4f90-b45a-7b957fbd700b","type":"CategoricalTickFormatter"},"major_label_orientation":-0.75,"major_label_text_font_size":{"value":"9pt"},"minor_tick_line_color":{"value":null},"plot":{"id":"7128feac-622d-4eb8-9811-2e8e21c869b8","subtype":"Figure","type":"Plot"},"ticker":{"id":"47dae8a2-bde0-4fa5-ac19-4f3b3418f1e9","type":"CategoricalTicker"}},"id":"e84ef118-9b3b-402a-9de7-58b8ff8b3d75","type":"CategoricalAxis"},{"attributes":{"angle":{"units":"rad","value":-0.5},"level":"glyph","plot":{"id":"7128feac-622d-4eb8-9811-2e8e21c869b8","subtype":"Figure","type":"Plot"},"source":{"id":"7594d644-914c-495e-ad40-75dcf5b7d58a","type":"ColumnDataSource"},"text":{"field":"pcts"},"text_align":"center","text_font_size":{"value":"7pt"},"x":{"field":"x"},"y":{"field":"top"},"y_offset":{"value":5}},"id":"c3da0f88-31bc-4016-932f-7edb3dfa7492","type":"LabelSet"},{"attributes":{"source":{"id":"421e6bf1-c855-4ae9-ab0d-1fdbd6440ee7","type":"ColumnDataSource"}},"id":"1519f427-6678-4b8e-9004-4b7b1369e646","type":"CDSView"},{"attributes":{"align":"center","plot":null,"text":"Trips Taken From Top 20 Destination Stations","text_font_size":{"value":"16pt"}},"id":"7212ee1c-0d77-4fb5-a58b-a3b8ef510a86","type":"Title"},{"attributes":{},"id":"573e1b3b-f373-4023-97f8-24e2867d1544","type":"BasicTicker"},{"attributes":{"use_scientific":false},"id":"1ef41329-2bd9-4b83-95da-8b49a828d47a","type":"BasicTickFormatter"},{"attributes":{"below":[{"id":"e84ef118-9b3b-402a-9de7-58b8ff8b3d75","type":"CategoricalAxis"}],"left":[{"id":"4ff1f14f-c2cd-4a02-8749-fc7a77f83526","type":"LinearAxis"}],"renderers":[{"id":"e84ef118-9b3b-402a-9de7-58b8ff8b3d75","type":"CategoricalAxis"},{"id":"4d6f2f4b-a938-474e-b7b1-64f6ec87e568","type":"Grid"},{"id":"4ff1f14f-c2cd-4a02-8749-fc7a77f83526","type":"LinearAxis"},{"id":"2cd2ce3a-b422-437f-bb4c-aaf65531c30a","type":"Grid"},{"id":"1c4a5a6f-38b8-47d1-9ca6-bb442478f66b","type":"BoxAnnotation"},{"id":"6a5de289-a9fc-4e4c-b5c0-b999c3e57753","type":"GlyphRenderer"},{"id":"c3da0f88-31bc-4016-932f-7edb3dfa7492","type":"LabelSet"}],"title":{"id":"7212ee1c-0d77-4fb5-a58b-a3b8ef510a86","type":"Title"},"toolbar":{"id":"c0db4be9-40e7-4ae2-925c-544865f40dbd","type":"Toolbar"},"x_range":{"id":"4358fd4b-750b-41b5-b12a-e25665bca22c","type":"FactorRange"},"x_scale":{"id":"4ff8faac-d3d2-4ce9-ab57-440744ffd41b","type":"CategoricalScale"},"y_range":{"id":"0bf114d7-eaa6-4163-9ce1-63d785acd067","type":"DataRange1d"},"y_scale":{"id":"d7405e6b-5ccc-4c0c-98d5-9c1759fa6388","type":"LinearScale"}},"id":"7128feac-622d-4eb8-9811-2e8e21c869b8","subtype":"Figure","type":"Plot"},{"attributes":{"callback":null,"column_names":["pcts","x","top"],"data":{"pcts":["0.93%","0.82%","0.69%","0.69%","0.65%","0.64%","0.63%","0.61%","0.54%","0.53%","0.52%","0.52%","0.48%","0.48%","0.48%","0.47%","0.47%","0.47%","0.47%","0.46%"],"top":[16089,14122,12006,11991,11272,11092,10993,10645,9314,9213,9026,9001,8365,8297,8256,8196,8084,8072,8070,8005],"x":["Pershing Square North","West St & Chambers St","Broadway & E 22 St","E 17 St & Broadway","12 Ave & W 40 St","W 20 St & 11 Ave","W 21 St & 6 Ave","8 Ave & W 31 St","Carmine St & 6 Ave","8 Ave & W 33 St","W 38 St & 8 Ave","South End Ave & Liberty St","Greenwich Ave & 8 Ave","W 18 St & 6 Ave","Broadway & E 14 St","W 41 St & 8 Ave","Cleveland Pl & Spring St","E 7 St & Avenue A","Central Park S & 6 Ave","Christopher St & Greenwich St"]}},"id":"7594d644-914c-495e-ad40-75dcf5b7d58a","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"top":{"field":"top"},"width":{"value":0. ...

# %% [markdown]
# # Other stuff to plot
# - DONE most imbalanced stations (ratio btwn origin/dest)
# - heatmap of all ratios of balance (symmetric matrix)
#     - to make it a PGM...represent each station as a node and draw weighted lines between?...
# - DONE most pop dest for each of the popular origin
# - DONE most pop origin for each of the popular dest
# - DONE most pop dest/orig for subscriber/customer

# %% [markdown]
# # Learning
# - learn destination station from origin station
#     - may be easier to have binary choice (i.e. central park vs not central park
# - learn destination station from origin station and type of rider

# %% [markdown]
# ### Most popular destination for each of the top 20 origin stations
# - find the most used destinations from those top 20 origins
# - how many of those destinations are in the overall top 20 destinations?

# %%
temp = data[data.startstationid.isin(topstart)]
topdests = temp.groupby('endstationid').count().max(1).sort_values(ascending=False)[0:20]

# %%
topdestnames = []
for idx,elem in enumerate(topdests.index):
    name = data[data.endstationid==elem].endstationname.unique()[0]
    print str(idx+1)+")"+name
    if np.intersect1d(name,topendnames).shape[0]==0:
        topdestnames.append(name)
    else :
        topdestnames.append('* '+name)
print idx
topdestnames
# Out:
# 1)West St & Chambers St
# 2)Pershing Square North
# 3)12 Ave & W 40 St
# 4)W 20 St & 11 Ave
# 5)Broadway & E 22 St
# 6)W 21 St & 6 Ave
# 7)9 Ave & W 22 St
# 8)E 17 St & Broadway
# 9)Christopher St & Greenwich St
# 10)Carmine St & 6 Ave
# 11)6 Ave & W 33 St
# 12)W 22 St & 10 Ave
# 13)W 16 St & The High Line
# 14)Pier 40 - Hudson River Park
# 15)8 Ave & W 31 St
# 16)W 38 St & 8 Ave
# 17)Central Park S & 6 Ave
# 18)Washington St & Gansevoort St
# 19)E 7 St & Avenue A
# 20)W 22 St & 8 Ave
# 19
# ['* West St & Chambers St',
#  '* Pershing Square North',
#  '* 12 Ave & W 40 St',
#  '* W 20 St & 11 Ave',
#  '* Broadway & E 22 St',
#  '* W 21 St & 6 Ave',
#  '9 Ave & W 22 St',
#  '* E 17 St & Broadway',
#  '* Christopher St & Greenwich St',
#  '* Carmine St & 6 Ave',
#  '6 Ave & W 33 St',
#  'W 22 St & 10 Ave',
#  'W 16 St & The High Line',
#  'Pier 40 - Hudson River Park',
#  '* 8 Ave & W 31 St',
#  '* W 38 St & 8 Ave',
#  '* Central Park S & 6 Ave',
#  'Washington St & Gansevoort St',
#  '* E 7 St & Avenue A',
#  'W 22 St & 8 Ave']

# %%
p = figure(x_range = topdestnames)
standardize(p)
standardizevbar(p)

x=topdestnames
top = topdests.values
width = 0.85
bottom = 0
p.vbar(x=x,top=top,width=width,bottom=bottom,color='skyblue');

pcts = top/temp.shape[0]*100
pcts = np.round(pcts,2)
pctsStrings = []
for i in range(pcts.size):
    pctsStrings.append(str(pcts[i]) + "%")
source = ColumnDataSource(data=dict(x=x,
                                   top=top,
                                   pcts=pctsStrings))
labels = LabelSet(x='x',y='top',text='pcts',
                 level='glyph',x_offset=0,y_offset=5,
                 source=source,render_mode='canvas',
                 text_align='center',text_font_size='7pt',angle=-0.5)
p.add_layout(labels)
print(str(sum(topdests.values/temp.shape[0])*100) + '% of trips taken from the top 20 stations ended at these stations')

p.title.text = 'Top 20 Destinations of Trips from Top Origin Stations'
p.xaxis.axis_label = 'Station Name'
p.yaxis.axis_label = '# of trips'

p.left[0].formatter.use_scientific = False
# Out:
# 17.6923576651% of trips taken from the top 20 stations ended at these stations

# %%
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="4d20ff85-f2a0-4a4b-9129-81a5eb0ad3e6"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("4d20ff85-f2a0-4a4b-9129-81a5eb0ad3e6");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("4d20ff85-f2a0-4a4b-9129-81a5eb0ad3e6");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '4d20ff85-f2a0-4a4b-9129-81a5eb0ad3e6' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"808a5a70-f9bc-4147-b248-317e26aee88d":{"roots":{"references":[{"attributes":{"grid_line_color":{"value":null},"plot":{"id":"a4dc3181-5443-48f4-86f1-d1800e1f2ed1","subtype":"Figure","type":"Plot"},"ticker":{"id":"5a51b376-682d-48cc-ac98-fd41a702108a","type":"CategoricalTicker"}},"id":"6c5b6d2a-a201-4df3-9f1b-fc25622b6617","type":"Grid"},{"attributes":{"source":{"id":"74c63af5-d44f-40c8-9d91-a3e836e867ac","type":"ColumnDataSource"}},"id":"c358e21f-e204-434b-96ff-0d0f298fd523","type":"CDSView"},{"attributes":{"callback":null,"factors":["* West St & Chambers St","* Pershing Square North","* 12 Ave & W 40 St","* W 20 St & 11 Ave","* Broadway & E 22 St","* W 21 St & 6 Ave","9 Ave & W 22 St","* E 17 St & Broadway","* Christopher St & Greenwich St","* Carmine St & 6 Ave","6 Ave & W 33 St","W 22 St & 10 Ave","W 16 St & The High Line","Pier 40 - Hudson River Park","* 8 Ave & W 31 St","* W 38 St & 8 Ave","* Central Park S & 6 Ave","Washington St & Gansevoort St","* E 7 St & Avenue A","W 22 St & 8 Ave"]},"id":"b32e189b-9ea4-4d34-90ff-6700bda5f0ac","type":"FactorRange"},{"attributes":{"callback":null,"start":0},"id":"7e0c0f30-a890-4634-a91f-7e38676375d7","type":"DataRange1d"},{"attributes":{},"id":"865a4978-11e7-4b9a-ae6c-b0ae8cfb5093","type":"CategoricalTickFormatter"},{"attributes":{},"id":"fe4e7f3d-0153-4808-8018-347e40415ebe","type":"BasicTicker"},{"attributes":{"fill_color":{"value":"skyblue"},"line_color":{"value":"skyblue"},"top":{"field":"top"},"width":{"value":0.85},"x":{"field":"x"}},"id":"4ee3bf48-0103-423b-9af6-1d6939e7802a","type":"VBar"},{"attributes":{"axis_label":"Station Name","axis_label_text_font_size":{"value":"14pt"},"formatter":{"id":"865a4978-11e7-4b9a-ae6c-b0ae8cfb5093","type":"CategoricalTickFormatter"},"major_label_orientation":-0.75,"major_label_text_font_size":{"value":"9pt"},"minor_tick_line_color":{"value":null},"plot":{"id":"a4dc3181-5443-48f4-86f1-d1800e1f2ed1","subtype":"Figure","type":"Plot"},"ticker":{"id":"5a51b376-682d-48cc-ac98-fd41a702108a","type":"CategoricalTicker"}},"id":"4aee0e1c-36c6-4ad6-938e-cc17abb9c20b","type":"CategoricalAxis"},{"attributes":{"data_source":{"id":"74c63af5-d44f-40c8-9d91-a3e836e867ac","type":"ColumnDataSource"},"glyph":{"id":"4ee3bf48-0103-423b-9af6-1d6939e7802a","type":"VBar"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"40d62dd4-22e0-44cc-bcd2-1826fcc69100","type":"VBar"},"selection_glyph":null,"view":{"id":"c358e21f-e204-434b-96ff-0d0f298fd523","type":"CDSView"}},"id":"e18c8bae-c2e3-455e-bfbe-492ce63f0014","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["pcts","x","top"],"data":{"pcts":["1.4%","1.16%","1.14%","1.14%","0.99%","0.96%","0.95%","0.9%","0.8%","0.79%","0.77%","0.77%","0.76%","0.76%","0.75%","0.74%","0.74%","0.74%","0.73%","0.69%"],"top":[2804,2322,2291,2280,1986,1914,1892,1797,1601,1585,1549,1544,1515,1513,1504,1487,1482,1482,1468,1388],"x":["* West St & Chambers St","* Pershing Square North","* 12 Ave & W 40 St","* W 20 St & 11 Ave","* Broadway & E 22 St","* W 21 St & 6 Ave","9 Ave & W 22 St","* E 17 St & Broadway","* Christopher St & Greenwich St","* Carmine St & 6 Ave","6 Ave & W 33 St","W 22 St & 10 Ave","W 16 St & The High Line","Pier 40 - Hudson River Park","* 8 Ave & W 31 St","* W 38 St & 8 Ave","* Central Park S & 6 Ave","Washington St & Gansevoort St","* E 7 St & Avenue A","W 22 St & 8 Ave"]}},"id":"ab7441f5-7605-44b3-819c-02aed97f506c","type":"ColumnDataSource"},{"attributes":{},"id":"0910af98-f60d-47e1-b55a-a833c9760766","type":"PanTool"},{"attributes":{"dimension":1,"plot":{"id":"a4dc3181-5443-48f4-86f1-d1800e1f2ed1","subtype":"Figure","type":"Plot"},"ticker":{"id":"fe4e7f3d-0153-4808-8018-347e40415ebe","type":"BasicTicker"}},"id":"7045b903-7b9e-4951-8399-3702e7d03a1f","type":"Grid"},{"attributes":{"use_scientific":false},"id":"93e2e10a-7749-4bae-a6bf-04ab2db7fa12","type":"BasicTickFormatter"},{"attributes":{},"id":"68c2877d-ee9d-4c09-9f19-126e164aacc7","type":"WheelZoomTool"}, ...

# %% [markdown]
# ### Most popular origin for each of the top 20 end stations
# - find the most used origins from those top 20 destinations
# - how many of those origins are in the overall top 20 starts?

# %%
temp = data[data.endstationid.isin(topend)]
toporigins = temp.groupby('startstationid').count().max(1).sort_values(ascending=False)[0:20]

# %%
toporiginnames = []
for idx,elem in enumerate(toporigins.index):
    name = data[data.startstationid==elem].startstationname.unique()[0]
    print str(idx+1)+")"+name
    if np.intersect1d(name,topstartnames).shape[0]==0:
        toporiginnames.append(name)
    else :
        toporiginnames.append('~ '+name)
print idx
toporiginnames
# Out:
# 1)West St & Chambers St
# 2)12 Ave & W 40 St
# 3)W 20 St & 11 Ave
# 4)Pershing Square North
# 5)Broadway & E 22 St
# 6)E 17 St & Broadway
# 7)8 Ave & W 16 St
# 8)W 21 St & 6 Ave
# 9)Washington St & Gansevoort St
# 10)9 Ave & W 22 St
# 11)Greenwich Ave & 8 Ave
# 12)Pier 40 - Hudson River Park
# 13)Carmine St & 6 Ave
# 14)Lafayette St & E 8 St
# 15)Cooper Square & E 7 St
# 16)Christopher St & Greenwich St
# 17)South End Ave & Liberty St
# 18)W 13 St & Hudson St
# 19)W 16 St & The High Line
# 20)W 22 St & 10 Ave
# 19
# ['~ West St & Chambers St',
#  '~ 12 Ave & W 40 St',
#  '~ W 20 St & 11 Ave',
#  '~ Pershing Square North',
#  '~ Broadway & E 22 St',
#  '~ E 17 St & Broadway',
#  '8 Ave & W 16 St',
#  '~ W 21 St & 6 Ave',
#  'Washington St & Gansevoort St',
#  '9 Ave & W 22 St',
#  '~ Greenwich Ave & 8 Ave',
#  'Pier 40 - Hudson River Park',
#  '~ Carmine St & 6 Ave',
#  'Lafayette St & E 8 St',
#  '~ Cooper Square & E 7 St',
#  'Christopher St & Greenwich St',
#  '~ South End Ave & Liberty St',
#  'W 13 St & Hudson St',
#  'W 16 St & The High Line',
#  'W 22 St & 10 Ave']

# %%
p = figure(x_range = toporiginnames)
standardize(p)
standardizevbar(p)

x=toporiginnames
top = toporigins.values
width = 0.85
bottom = 0
p.vbar(x=x,top=top,width=width,bottom=bottom,color='skyblue');

pcts = top/temp.shape[0]*100
pcts = np.round(pcts,2)
pctsStrings = []
for i in range(pcts.size):
    pctsStrings.append(str(pcts[i]) + "%")
source = ColumnDataSource(data=dict(x=x,
                                   top=top,
                                   pcts=pctsStrings))
labels = LabelSet(x='x',y='top',text='pcts',
                 level='glyph',x_offset=0,y_offset=5,
                 source=source,render_mode='canvas',
                 text_align='center',text_font_size='7pt',angle=-0.5)
p.add_layout(labels)
print(str(sum(toporigins.values/temp.shape[0])*100) + '% of trips ending at the top 20 stations started at these stations')

p.title.text = 'Top 20 Origins of Trips from Top Destination Stations'
p.xaxis.axis_label = 'Station Name'
p.yaxis.axis_label = '# of trips'

p.left[0].formatter.use_scientific = False
# Out:
# 18.56% of total trips started at these stations
# 18.5593851351% of trips ending at the top 20 stations started at these stations

# %%
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="f5386193-d487-4eb9-bfae-0e088ea4d586"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("f5386193-d487-4eb9-bfae-0e088ea4d586");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f5386193-d487-4eb9-bfae-0e088ea4d586");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f5386193-d487-4eb9-bfae-0e088ea4d586' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"9931a2c4-e497-4e67-a0cc-062619ccd9a6":{"roots":{"references":[{"attributes":{"use_scientific":false},"id":"b01d2e56-d259-44c5-87f1-25735aa9846d","type":"BasicTickFormatter"},{"attributes":{"fill_color":{"value":"skyblue"},"line_color":{"value":"skyblue"},"top":{"field":"top"},"width":{"value":0.85},"x":{"field":"x"}},"id":"d8b7119f-4217-45f5-b9ce-956550199782","type":"VBar"},{"attributes":{"callback":null,"start":0},"id":"9d706ab3-e693-453c-b891-9efd7b425796","type":"DataRange1d"},{"attributes":{"source":{"id":"ec698a93-efac-4efd-8494-02e25c3a5d1b","type":"ColumnDataSource"}},"id":"8c0161b3-7f19-4e3b-8ee9-9b8bd2d1e767","type":"CDSView"},{"attributes":{},"id":"34c0e245-eef6-4c7f-9f1d-eee7b9b52d33","type":"LinearScale"},{"attributes":{"angle":{"units":"rad","value":-0.5},"level":"glyph","plot":{"id":"d16abcbc-da89-4368-ac98-088398f57b4a","subtype":"Figure","type":"Plot"},"source":{"id":"9d98c721-3c34-438e-8cfc-30433a174a5f","type":"ColumnDataSource"},"text":{"field":"pcts"},"text_align":"center","text_font_size":{"value":"7pt"},"x":{"field":"x"},"y":{"field":"top"},"y_offset":{"value":5}},"id":"1649dbb5-cbc9-4b17-b799-9bfde203e89d","type":"LabelSet"},{"attributes":{"callback":null,"factors":["~ West St & Chambers St","~ 12 Ave & W 40 St","~ W 20 St & 11 Ave","~ Pershing Square North","~ Broadway & E 22 St","~ E 17 St & Broadway","8 Ave & W 16 St","~ W 21 St & 6 Ave","Washington St & Gansevoort St","9 Ave & W 22 St","~ Greenwich Ave & 8 Ave","Pier 40 - Hudson River Park","~ Carmine St & 6 Ave","Lafayette St & E 8 St","~ Cooper Square & E 7 St","Christopher St & Greenwich St","~ South End Ave & Liberty St","W 13 St & Hudson St","W 16 St & The High Line","W 22 St & 10 Ave"]},"id":"b7dd2497-8279-468e-b653-199add6ac17a","type":"FactorRange"},{"attributes":{},"id":"b5c75f83-9202-4425-b46b-ff246c5e0caf","type":"ResetTool"},{"attributes":{},"id":"1d3fa346-1e5c-49bc-a27f-4ed488cc19eb","type":"SaveTool"},{"attributes":{"axis_label":"Station Name","axis_label_text_font_size":{"value":"14pt"},"formatter":{"id":"3bc85cd6-1e60-4c4c-952a-36db7c12fff9","type":"CategoricalTickFormatter"},"major_label_orientation":-0.75,"major_label_text_font_size":{"value":"9pt"},"minor_tick_line_color":{"value":null},"plot":{"id":"d16abcbc-da89-4368-ac98-088398f57b4a","subtype":"Figure","type":"Plot"},"ticker":{"id":"96f0e50f-d59c-4f76-b93e-6f867aa5c40f","type":"CategoricalTicker"}},"id":"9b8fdc11-5068-4d93-9fd7-c63e74f05ef1","type":"CategoricalAxis"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"37d20900-b5dc-4ac5-a982-eabc90db4abb","type":"BoxAnnotation"},{"attributes":{"callback":null,"column_names":["x","top"],"data":{"top":[2890,2494,2487,2188,2147,1940,1854,1846,1783,1741,1740,1659,1637,1605,1558,1557,1530,1511,1491,1481],"x":["~ West St & Chambers St","~ 12 Ave & W 40 St","~ W 20 St & 11 Ave","~ Pershing Square North","~ Broadway & E 22 St","~ E 17 St & Broadway","8 Ave & W 16 St","~ W 21 St & 6 Ave","Washington St & Gansevoort St","9 Ave & W 22 St","~ Greenwich Ave & 8 Ave","Pier 40 - Hudson River Park","~ Carmine St & 6 Ave","Lafayette St & E 8 St","~ Cooper Square & E 7 St","Christopher St & Greenwich St","~ South End Ave & Liberty St","W 13 St & Hudson St","W 16 St & The High Line","W 22 St & 10 Ave"]}},"id":"ec698a93-efac-4efd-8494-02e25c3a5d1b","type":"ColumnDataSource"},{"attributes":{},"id":"d2bd270a-4e41-4fc0-b50d-cbdd2cbedddf","type":"WheelZoomTool"},{"attributes":{},"id":"027e9b4e-40a3-4f70-a866-02ae9e7d3b44","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"d16abcbc-da89-4368-ac98-088398f57b4a","subtype":"Figure","type":"Plot"},"ticker":{"id":"027e9b4e-40a3-4f70-a866-02ae9e7d3b44","type":"BasicTicker"}},"id":"4109e86e-f9e7-4 ...

# %% [markdown]
# ### Most popular station for each type of customer
# For this analysis, we will not distinguish between start/end...just if a station was used or not
#
# ** NOTE:  this means the same trip may be counted twice!  that's fine, just don't compare to other hists **
#
# ** KEY **
#
# ~ = in top 20 start stations
#
# \* = in top 20 end stations
#
# ~\* = in both

# %%
subscribers = data[data.usertype==1]
customers = data[data.usertype==2]
unknowns = data[data.usertype==0]

print subscribers.shape[0]
print customers.shape[0]
print unknowns.shape[0]
# Out:
# 1516952
# 214642
# 0

# %% [markdown]
# #### For subscribers

# %%
ss = subscribers.groupby('startstationid').count().max(1).sort_values(ascending=False)[0:20]
se = subscribers.groupby('endstationid').count().max(1).sort_values(ascending=False)[0:20]

allPoss = np.union1d(ss.index,se.index)
totals = pd.Series(index=allPoss)
for idx,elem in enumerate(allPoss):
    try:
        a = ss.loc[elem]
    except:
        a=0
    try:
        b = se.loc[elem]
    except:
        b=0
    totals.loc[elem] = a+b
totals = totals.sort_values(ascending=False)
print totals.shape
totals
# Out:
# (23L,)
# 519     30551.0
# 402     21972.0
# 497     21706.0
# 426     21451.0
# 435     20877.0
# 3255    19756.0
# 459     18337.0
# 490     17735.0
# 523     16872.0
# 368     16448.0
# 477     16030.0
# 514     15752.0
# 168     15484.0
# 284     15418.0
# 285     15146.0
# 359     15088.0
# 382     14369.0
# 432      7685.0
# 3263     7509.0
# 3002     7272.0
# 293      7206.0
# 229      7184.0
# 379      7176.0
# dtype: float64

# %%
toptotalnames = []
for idx,elem in enumerate(totals.index):
    name = data[data.startstationid==elem].startstationname.unique()[0]
    print str(idx+1)+")"+name
    if (np.intersect1d(name,topstartnames).shape[0]!=0 and np.intersect1d(name,topendnames).shape[0]!=0):
        toptotalnames.append('~* ' + name)
    elif np.intersect1d(name,topstartnames).shape[0]!=0:
        toptotalnames.append('~ ' + name)
    elif np.intersect1d(name,topendnames).shape[0]!=0:
        toptotalnames.append('* ' + name)
    else :
        toptotalnames.append(name)
print idx
toptotalnames
# Out:
# 1)Pershing Square North
# 2)Broadway & E 22 St
# 3)E 17 St & Broadway
# 4)West St & Chambers St
# 5)W 21 St & 6 Ave
# 6)8 Ave & W 31 St
# 7)W 20 St & 11 Ave
# 8)8 Ave & W 33 St
# 9)W 38 St & 8 Ave
# 10)Carmine St & 6 Ave
# 11)W 41 St & 8 Ave
# 12)12 Ave & W 40 St
# 13)W 18 St & 6 Ave
# 14)Greenwich Ave & 8 Ave
# 15)Broadway & E 14 St
# 16)E 47 St & Park Ave
# 17)University Pl & E 14 St
# 18)E 7 St & Avenue A
# 19)Cooper Square & E 7 St
# 20)South End Ave & Liberty St
# 21)Lafayette St & E 8 St
# 22)Great Jones St
# 23)W 31 St & 7 Ave
# 22
# ['~* Pershing Square North',
#  '~* Broadway & E 22 St',
#  '~* E 17 St & Broadway',
#  '~* West St & Chambers St',
#  '~* W 21 St & 6 Ave',
#  '~* 8 Ave & W 31 St',
#  '~* W 20 St & 11 Ave',
#  '~* 8 Ave & W 33 St',
#  '~* W 38 St & 8 Ave',
#  '~* Carmine St & 6 Ave',
#  '~* W 41 St & 8 Ave',
#  '~* 12 Ave & W 40 St',
#  '~* W 18 St & 6 Ave',
#  '~* Greenwich Ave & 8 Ave',
#  '~* Broadway & E 14 St',
#  'E 47 St & Park Ave',
#  'University Pl & E 14 St',
#  '* E 7 St & Avenue A',
#  '~ Cooper Square & E 7 St',
#  '~* South End Ave & Liberty St',
#  'Lafayette St & E 8 St',
#  'Great Jones St',
#  'W 31 St & 7 Ave']

# %%
p = figure(x_range = toptotalnames)
standardize(p)
standardizevbar(p)

x=toptotalnames
top = totals.values
width = 0.85
bottom = 0
p.vbar(x=x,top=top,width=width,bottom=bottom,color='skyblue');

p.title.text = 'Top Stations Used By Subscribers'
p.xaxis.axis_label = 'Station Name'
p.yaxis.axis_label = '# of trips starting or ending'

p.left[0].formatter.use_scientific = False

# %%
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="a1c79c0d-17cf-4330-8861-b124a4e623ef"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("a1c79c0d-17cf-4330-8861-b124a4e623ef");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a1c79c0d-17cf-4330-8861-b124a4e623ef");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a1c79c0d-17cf-4330-8861-b124a4e623ef' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"24a87a4f-8e2c-4113-a507-6e8a4a0c26d3":{"roots":{"references":[{"attributes":{"axis_label":"Station Name","axis_label_text_font_size":{"value":"14pt"},"formatter":{"id":"1287276c-330e-4a6d-b443-ed36d75eff9e","type":"CategoricalTickFormatter"},"major_label_orientation":-0.75,"major_label_text_font_size":{"value":"9pt"},"minor_tick_line_color":{"value":null},"plot":{"id":"91942982-4f9d-4a6c-9f79-75d8c8425e6d","subtype":"Figure","type":"Plot"},"ticker":{"id":"c54ed631-943d-49ef-80bc-7b80e3833088","type":"CategoricalTicker"}},"id":"e59f4947-43f0-4829-b9b6-f9b16f0e1863","type":"CategoricalAxis"},{"attributes":{},"id":"1287276c-330e-4a6d-b443
0f56","type":"LinearAxis"},{"id":"a34bed85-fd8f-411c-a74a-08e25ed1d5fc","type":"Grid"},{"id":"ffa0cc06-9260-4d84-8d7e-634f8025c4fd","type":"BoxAnnotation"},{"id":"c16c41cd-2ab8-4021-8e00-775bf8dd3709","type":"GlyphRenderer"}],"title":{"id":"7d45772c-33c9-4eaa-a863-654d1a1c0c88","type":"Title"},"toolbar":{"id":"4c4bcc60-b939-4f7a-a3ce-1a4072200b74","type":"Toolbar"},"x_range":{"id":"cee1ed19-1d5c-42fa-8d24-7b2fc59da97f","type":"FactorRange"},"x_scale":{"id":"fec6d5a9-c993-4acc-8816-634db5e7d5ff","type":"CategoricalScale"},"y_range":{"id":"2f125dd6-5528-481f-b8b2-acaf5ee860e6","type":"DataRange1d"},"y_scale":{"id":"a312a33b-9eec-47b3-9d17-e18e7b0c9346","type":"LinearScale"}},"id":"91942982-4f9d-4a6c-9f79-75d8c8425e6d","subtype":"Figure","t ...

# %% [markdown]
# #### For customers

# %%
ss = customers.groupby('startstationid').count().max(1).sort_values(ascending=False)[0:20]
se = customers.groupby('endstationid').count().max(1).sort_values(ascending=False)[0:20]

allPoss = np.union1d(ss.index,se.index)
totals = pd.Series(index=allPoss)
for idx,elem in enumerate(allPoss):
    try:
        a = ss.loc[elem]
    except:
        a=0
    try:
        b = se.loc[elem]
    except:
        b=0
    totals.loc[elem] = a+b
totals = totals.sort_values(ascending=False)
print totals.shape
totals
# Out:
# (21L,)
# 2006    8513.0
# 387     7491.0
# 514     6821.0
# 426     6213.0
# 3282    5884.0
# 281     5673.0
# 3165    5267.0
# 3374    4984.0
# 3137    4512.0
# 405     3996.0
# 3256    3954.0
# 217     3954.0
# 2008    3786.0
# 499     3601.0
# 3002    3523.0
# 459     3329.0
# 3143    3166.0
# 3163    3083.0
# 532     2917.0
# 3160    1662.0
# 457     1526.0
# dtype: float64

# %%
toptotalnames = []
for idx,elem in enumerate(totals.index):
    name = data[data.startstationid==elem].startstationname.unique()[0]
    print str(idx+1)+")"+name
    if (np.intersect1d(name,topstartnames).shape[0]!=0 and np.intersect1d(name,topendnames).shape[0]!=0):
        toptotalnames.append('~* ' + name)
    elif np.intersect1d(name,topstartnames).shape[0]!=0:
        toptotalnames.append('~ ' + name)
    elif np.intersect1d(name,topendnames).shape[0]!=0:
        toptotalnames.append('* ' + name)
    else :
        toptotalnames.append(name)
print idx
toptotalnames
# Out:
# 1)Central Park S & 6 Ave
# 2)Centre St & Chambers St
# 3)12 Ave & W 40 St
# 4)West St & Chambers St
# 5)5 Ave & E 88 St
# 6)Grand Army Plaza & Central Park S
# 7)Central Park West & W 72 St
# 8)Central Park North & Adam Clayton Powell Blvd
# 9)5 Ave & E 73 St
# 10)Washington St & Gansevoort St
# 11)Pier 40 - Hudson River Park
# 12)Old Fulton St
# 13)Little West St & 1 Pl
# 14)Broadway & W 60 St
# 15)South End Ave & Liberty St
# 16)W 20 St & 11 Ave
# 17)5 Ave & E 78 St
# 18)Central Park West & W 68 St
# 19)S 5 Pl & S 4 St
# 20)Central Park West & W 76 St
# 21)Broadway & W 58 St
# 20
# ['~* Central Park S & 6 Ave',
#  'Centre St & Chambers St',
#  '~* 12 Ave & W 40 St',
#  '~* West St & Chambers St',
#  '5 Ave & E 88 St',
#  '~ Grand Army Plaza & Central Park S',
#  'Central Park West & W 72 St',
#  'Central Park North & Adam Clayton Powell Blvd',
#  '5 Ave & E 73 St',
#  'Washington St & Gansevoort St',
#  'Pier 40 - Hudson River Park',
#  'Old Fulton St',
#  'Little West St & 1 Pl',
#  'Broadway & W 60 St',
#  '~* South End Ave & Liberty St',
#  '~* W 20 St & 11 Ave',
#  '5 Ave & E 78 St',
#  'Central Park West & W 68 St',
#  'S 5 Pl & S 4 St',
#  'Central Park West & W 76 St',
#  'Broadway & W 58 St']

# %%
p = figure(x_range = toptotalnames)
standardize(p)
standardizevbar(p)

x=toptotalnames
top = totals.values
width = 0.85
bottom = 0
p.vbar(x=x,top=top,width=width,bottom=bottom,color='skyblue');

p.title.text = 'Top Stations Used By Short-Term Customers'
p.xaxis.axis_label = 'Station Name'
p.yaxis.axis_label = '# of trips starting or ending'

p.left[0].formatter.use_scientific = False

# %%
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="919f6d0c-89a5-45ca-a294-f8970a1e87d3"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("919f6d0c-89a5-45ca-a294-f8970a1e87d3");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("919f6d0c-89a5-45ca-a294-f8970a1e87d3");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '919f6d0c-89a5-45ca-a294-f8970a1e87d3' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"82ff4d43-d14d-4724-aafa-bed17d5050d0":{"roots":{"references":[{"attributes":{"callback":null,"factors":["~* Central Park S & 6 Ave","Centre St & Chambers St","~* 12 Ave & W 40 St","~* West St & Chambers St","5 Ave & E 88 St","~ Grand Army Plaza & Central Park S","Central Park West & W 72 St","Central Park North & Adam Clayton Powell Blvd","5 Ave & E 73 St","Washington St & Gansevoort St","Pier 40 - Hudson River Park","Old Fulton St","Little West St & 1 Pl","Broadway & W 60 St","~* South End Ave & Liberty St","~* W 20 St & 11 Ave","5 Ave & E 78 St","Central Park West & W 68 St","S 5 Pl & S 4 St","Central Park West & W 76 St","Broadway & W 58 St"]},"id":"002cd1a5-e169-42b1-9ff1-dabfdf3192ca","type":"FactorRange"},{"attributes":{"dimension":1,"plot":{"id":"a189e02d-9249-421e-8b9e-24cad3056e84","subtype":"Figure","type":"Plot"},"ticker":{"id":"69c6ba92-9d19-4cc2-ac9a-07de422713ce","type":"BasicTicker"}},"id":"0e0d62b4-3035-41c4-b0b9-8a23ce0114d5","type":"Grid"},{"attributes":{"align":"center","plot":null,"text":"Top Stations Used By Short-Term Customers","text_font_size":{"value":"16pt"}},"id":"f8f6b7a2-7b94-40e4-a171-378248b666ae","type":"Title"},{"attributes":{},"id":"c5195436-0d49-44d5-b732-ae35f9c13fd6","type":"CategoricalTicker"},{"attributes":{"fill_color":{"value":"skyblue"},"line_color":{"value":"skyblue"},"top":{"field":"top"},"width":{"value":0.85},"x":{"field":"x"}},"id":"e53b8dc8-d4e2-4bc7-ae3b-78f3ec86bb1a","type":"VBar"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"0edeb864-6b6b-4c09-a6d1-6f13cbccd91f","type":"PanTool"},{"id":"15c6affd-57fb-4029-9309-49e956980767","type":"WheelZoomTool"},{"id":"7c12fb21-ce21-4d9b-b895-aeea4044329b","type":"BoxZoomTool"},{"id":"08f539fb-b413-4b62-bbbe-da6ec40b51f4","type":"SaveTool"},{"id":"1252ef39-1fd4-4bd6-bcb5-8de580077a01","type":"ResetTool"},{"id":"7ffd7e65-909a-4f70-8ca8-63867cd57d54","type":"HelpTool"}]},"id":"22e7e20a-ecb8-4127-8a22-8f55372eb10e","type":"Toolbar"},{"attributes":{},"id":"89531226-f2a9-4cd8-94b5-37a10c8c80f1","type":"CategoricalScale"},{"attributes":{"overlay":{"id":"9bddca05-3ed4-49ea-ba39-79301473c442","type":"BoxAnnotation"}},"id":"7c12fb21-ce21-4d9b-b895-aeea4044329b","type":"BoxZoomTool"},{"attributes":{},"id":"0edeb864-6b6b-4c09-a6d1-6f13cbccd91f","type":"PanTool"},{"attributes":{},"id":"a0f49f6b-82a6-4ce7-8474-6b762b7bba82","type":"LinearScale"},{"attributes":{"source":{"id":"0def71d0-ce66-4a57-953c-1fd8cc57bcbb","type":"ColumnDataSource"}},"id":"e567cc0a-fd05-43aa-97b6-9601c7052545","type":"CDSView"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"9bddca05-3ed4-49ea-ba39-79301473c442","type":"BoxAnnotation"},{"attributes":{"axis_label":"Station Name","axis_label_text_font_size":{"value":"14pt"},"formatter":{"id":"c3264ce3-2937-4a01-981a-a5e84338b6cb","type":"CategoricalTickFormatter"},"major_label_orientation":-0.75,"major_label_text_font_size":{"value":"9pt"},"minor_tick_line_color":{"value":null},"plot":{"id":"a189e02d-9249-421e-8b9e-24cad3056e84","subtype":"Figure","type":"Plot"},"ticker":{"id":"c5195436-0d49-44d5-b732-ae35f9c13fd6","type":"CategoricalTicker"}},"id":"e915b4b3-2c8b-41ba-999a-4d29a2698945","type":"CategoricalAxis"},{"attributes":{},"id":"7ffd7e65-909a-4f70-8ca8-63867cd57d54","type":"HelpTool"},{"attributes":{"callback":null,"start":0},"id":"74063044-d462-4e21-a41c-042f00025c81","type":"DataRange1d"},{"attributes":{"use_scientific":false},"id":"f9b57277-0679-4bd4-bb18-ce0212935fe1","type":"BasicTickFormatter"},{"attributes":{},"id":"c3264ce3-2937-4a01-981a-a5e84338b6cb","type":"CategoricalTickFormatter"},{"attributes":{"grid_line_color":{"value":null},"plot":{"id ...

# %% [markdown]
# ### What is the ratio of start/stop for each of the stations?

# %%
starts = data.startstationid.value_counts()
ends = data.endstationid.value_counts()

# %%
ratios = pd.Series(index=starts.index)
ctr=0
for idx,elem in enumerate(starts.index):
    ratios.loc[elem] = starts.loc[elem]/ends.loc[elem]
#     if idx<100:
#         print starts.loc[elem]
#         print ends.loc[elem]
#         print '-----------------------------------'
    if starts.loc[elem]==ends.loc[elem]:
        ctr=ctr+1
ratios
# Out:
# 519     1.017092
# 426     0.958929
# 497     0.975982
# 402     0.948526
# 514     1.002573
# 435     0.990539
# 459     0.953300
# 3255    0.986097
# 490     1.086400
# 368     0.981533
# 281     1.251533
# 523     0.994460
# 3002    0.996334
# 477     1.093704
# 2006    1.041264
# 284     0.991990
# 285     1.001453
# 151     0.997402
# 168     0.970230
# 3263    1.088450
# 358     0.974766
# 293     1.001813
# 382     0.997280
# 359     0.970592
# 229     0.991212
# 379     1.063090
# 128     0.998542
# 505     0.998933
# 444     0.996920
# 492     1.059817
#           ...
# 3063    1.054217
# 3127    1.026866
# 3061    0.981982
# 3302    1.088339
# 3044    1.016611
# 119     0.971154
# 3327    1.057348
# 3342    0.761111
# 3456    1.030888
# 2005    0.936170
# 3075    1.078189
# 3352    0.941818
# 3337    0.786164
# 3395    0.975490
# 3340    0.855263
# 3326    0.885572
# 3245    0.934426
# 3394    0.906977
# 3330    0.852761
# 3333    0.708108
# 3257    1.189655
# 3432    0.270642
# 3468    0.941176
# 3474    1.037037
# 3250    0.187500
# 3470    1.000000
# 3036    1.000000
# 3239    1.000000
# 3248    0.666667
# 3040    1.000000
# dtype: float64

# %% [markdown]
# #### The stations with more starts than stops

# %%
temp = ratios.sort_values(ascending=False)
temp = temp[0:20]

# %%
names = []
for idx,elem in enumerate(temp.index):
    name = data[data.startstationid==elem].startstationname.unique()[0]
    print str(idx+1)+")"+name
    if (np.intersect1d(name,topstartnames).shape[0]!=0 and np.intersect1d(name,topendnames).shape[0]!=0):
        names.append('~* ' + name)
    elif np.intersect1d(name,topstartnames).shape[0]!=0:
        names.append('~ ' + name)
    elif np.intersect1d(name,topendnames).shape[0]!=0:
        names.append('* ' + name)
    else :
        names.append(name)
print idx
# Out:
# 1)Monroe St & Classon Ave
# 2)Lafayette Ave & St James Pl
# 3)Bedford Ave & S 9 St
# 4)Grand Army Plaza & Central Park S
# 5)Columbus Ave & W 72 St
# 6)Clark St & Henry St
# 7)Bialystoker Pl & Delancey St
# 8)Adventures NYC
# 9)Columbia Heights & Cranberry St
# 10)W 76 St & Columbus Ave
# 11)Central Park West & W 76 St
# 12)Hancock St & Bedford Ave
# 13)W 84 St & Broadway
# 14)DeKalb Ave & Vanderbilt Ave
# 15)W 42 St & Dyer Ave
# 16)Clermont Ave & Lafayette Ave
# 17)Broadway & W 53 St
# 18)Fulton St & Clermont Ave
# 19)Central Park West & W 85 St
# 20)Central Park West & W 72 St
# 19

# %%
p = figure(x_range = names)
standardize(p)
standardizevbar(p)

x=names
top = temp.values
width = 0.85
bottom = 0
p.vbar(x=x,top=top,width=width,bottom=bottom,color='skyblue');
p.line(x=x,y=np.ones(20), line_width=2)

p.title.text = 'Most Imbalanced Stations - More Starts Than Ends'
p.xaxis.axis_label = 'Station Name'
p.yaxis.axis_label = '# trips starting / # trips ending'

p.left[0].formatter.use_scientific = False

# %%
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="0cc17860-34e5-4740-8926-d9baa9973027"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("0cc17860-34e5-4740-8926-d9baa9973027");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("0cc17860-34e5-4740-8926-d9baa9973027");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '0cc17860-34e5-4740-8926-d9baa9973027' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"964a977c-963e-4375-bb5f-9c93ab65873d":{"roots":{"references":[{"attributes":{"callback":null,"factors":["Monroe St & Classon Ave","Lafayette Ave & St James Pl","Bedford Ave & S 9 St","~ Grand Army Plaza & Central Park S","Columbus Ave & W 72 St","Clark St & Henry St","Bialystoker Pl & Delancey St","Adventures NYC","Columbia Heights & Cranberry St","W 76 St & Columbus Ave","Central Park West & W 76 St","Hancock St & Bedford Ave","W 84 St & Broadway","DeKalb Ave & Vanderbilt Ave","W 42 St & Dyer Ave","Clermont Ave & Lafayette Ave
axis_label_text_font_size":{"value":"14pt"},"formatter":{"id":"25395a2f-b1f6-4b20-b287-849adc95954e","type":"BasicTickFormatter"},"major_label_text_font_si ...

# %% [markdown]
# #### The stations with more stops than starts

# %%
temp = ratios.sort_values(ascending=True)
temp = temp[0+3:20+3]

# %%
names = []
for idx,elem in enumerate(temp.index):
    name = data[data.startstationid==elem].startstationname.unique()[0]
    print str(idx+1)+")"+name
    if (np.intersect1d(name,topstartnames).shape[0]!=0 and np.intersect1d(name,topendnames).shape[0]!=0):
        names.append('~* ' + name)
    elif np.intersect1d(name,topstartnames).shape[0]!=0:
        names.append('~ ' + name)
    elif np.intersect1d(name,topendnames).shape[0]!=0:
        names.append('* ' + name)
    else :
        names.append(name)
print idx
# Out:
# 1)DeKalb Ave & Hudson Ave
# 2)Columbia St & Lorraine St
# 3)Pioneer St & Richards St
# 4)Dwight St & Van Dyke St
# 5)Broadway & Battery Pl
# 6)E 7 St & Avenue A
# 7)Fulton St & Rockwell Pl
# 8)Henry St & Bay St
# 9)Wolcott St & Dwight St
# 10)Nassau St & Navy St
# 11)Commerce St & Van Brunt St
# 12)Sands St & Navy St
# 13)Clinton St & Centre St
# 14)Bond St & Fulton St
# 15)4 Ave & 2 St
# 16)Columbia St & W 9 St
# 17)Stanton St & Mangin St
# 18)Richards St & Delavan St
# 19)Pearl St & Anchorage Pl
# 20)Carlton Ave & Flushing Ave
# 19

# %%
p = figure(x_range = names)
standardize(p)
standardizevbar(p)

x=names
top = temp.values
width = 0.85
bottom = 0
p.vbar(x=x,top=top,width=width,bottom=bottom,color='skyblue');
p.line(x=x,y=np.ones(20), line_width=2)

p.title.text = 'Most Imbalanced Stations - More Ends Than Starts'
p.xaxis.axis_label = 'Station Name'
p.yaxis.axis_label = '# trips starting / # trips ending'

p.left[0].formatter.use_scientific = False

# %%
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="0d378bd4-0702-48ea-bb79-c1d58f1d6680"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("0d378bd4-0702-48ea-bb79-c1d58f1d6680");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("0d378bd4-0702-48ea-bb79-c1d58f1d6680");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '0d378bd4-0702-48ea-bb79-c1d58f1d6680' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"309bdcca-5b9d-4e90-af0c-be238154c2f2":{"roots":{"references":[{"attributes":{"grid_line_color":{"value":null},"plot":{"id":"d38905d9-91d7-4dc7-a836-6bb1ca553446","subtype":"Figure","type":"Plot"},"ticker":{"id":"19988141-f16c-452b-9d97-b0db548ade99","type":"CategoricalTicker"}},"id":"1d8d09e8-e776-4921-87f1-58d1443d167a","type":"Grid"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"f6d40db7-a90e-40c9-a754-3691a30be6b2","type":"PanTool"},{"id":"64e024c6-9cd8-4156-b178-ff57c04deed8","type":"WheelZoomTool"},{"id":"42d4d776-197f-4d35-b06e-a1831a56ebe8","type":"BoxZoomTool"},{"id":"cd289849-91f0-4459-b0e6-be7bc1849b57","type":"SaveTool"},{"id":"2c31b1fc-e4f6-499e-b513-38663c1251b1","type":"ResetTool"},{"id":"c1ea88cf-215e-410f-90bf-680ee66734bd","type":"HelpTool"}]},"id":"3b164488-3f54-4ad3-a7ef-497708ddb3e1","type":"Toolbar"},{"attributes":{},"id":"f6d40db7-a90e-40c9-a754-3691a30be6b2","type":"PanTool"},{"attributes":{},"id":"19988141-f16c-452b-9d97-b0db548ade99","type":"CategoricalTicker"},{"attributes":{"callback":null,"factors":["DeKalb Ave & Hudson Ave","Columbia St & Lorraine St","Pioneer St & Richards St","Dwight St & Van Dyke St","Broadway & Battery Pl","* E 7 St & Avenue A","Fulton St & Rockwell Pl","Henry St & Bay St","Wolcott St & Dwight St","Nassau St & Navy St","Commerce St & Van Brunt St","Sands St & Navy St","Clinton St & Centre St","Bond St & Fulton St","4 Ave & 2 St","Columbia St & W 9 St","Stanton St & Mangin St","Richards St & Delavan St","Pearl St & Anchorage Pl","Carlton Ave & Flushing Ave"]},"id":"f3b0f9a2-26f8-4b4b-996c-7f7c675cf63f","type":"FactorRange"},{"attributes":{},"id":"64e024c6-9cd8-4156-b178-ff57c04deed8","type":"WheelZoomTool"},{"attributes":{},"id":"3bda517f-5db5-4573-9952-50bae4e415ed","type":"CategoricalTickFormatter"},{"attributes":{},"id":"2c31b1fc-e4f6-499e-b513-38663c1251b1","type":"ResetTool"},{"attributes":{},"id":"bd997a9d-eccd-4c9e-9897-1767557c8f07","type":"CategoricalScale"},{"attributes":{"source":{"id":"798be078-94dc-4131-bbb4-25c70f34c290","type":"ColumnDataSource"}},"id":"00c0b2f4-7afd-44fa-a616-877f8c026626","type":"CDSView"},{"attributes":{"source":{"id":"aaf5e9d9-a3de-4c4b-8bb1-c0c7506dce20","type":"ColumnDataSource"}},"id":"9cba98df-0a8a-45a9-bd1d-a4e0911cf111","type":"CDSView"},{"attributes":{},"id":"fbdc1a6c-8c1b-46f8-ab58-54d0162ed2ab","type":"LinearScale"},{"attributes":{"data_source":{"id":"798be078-94dc-4131-bbb4-25c70f34c290","type":"ColumnDataSource"},"glyph":{"id":"ab88c72e-e16b-451d-85ae-50445846eb8a","type":"VBar"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"ffd07016-7bc7-4bc5-9e1b-48f8e7eefd0d","type":"VBar"},"selection_glyph":null,"view":{"id":"00c0b2f4-7afd-44fa-a616-877f8c026626","type":"CDSView"}},"id":"33b77f5b-2860-4dfb-82a1-13fae3dd1d9d","type":"GlyphRenderer"},{"attributes":{"align":"center","plot":null,"text":"Most Imbalanced Stations - More Ends Than Starts","text_font_size":{"value":"16pt"}},"id":"c5f0cec7-c3f4-4980-a532-514cbc11fc15","type":"Title"},{"attributes":{"axis_label":"Station Name","axis_label_text_font_size":{"value":"14pt"},"formatter":{"id":"3bda517f-5db5-4573-9952-50bae4e415ed","type":"CategoricalTickFormatter"},"major_label_orientation":-0.75,"major_label_text_font_size":{"value":"9pt"},"minor_tick_line_color":{"value":null},"plot":{"id":"d38905d9-91d7-4dc7-a836-6bb1ca553446","subtype":"Figure","type":"Plot"},"ticker":{"id":"19988141-f16c-452b-9d97-b0db548ade99","type":"CategoricalTicker"}},"id":"a25112f3-a55f-439a-ab67-1f3e67179cad","type":"CategoricalAxis"},{"attributes":{"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"0d67ed6d-3887-4b94-82dc-0f313dd71531","type":"Line"},{"attributes":{"callback":null,"start":0},"id":"1a6d6bbe-644a-4e2c-939d-8c104071005d","type":"DataRange1d"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width": ...

# %% [markdown]
# #### The most balanced stations

# %%
temp = ratios[(ratios.values==1) | ((ratios.values<=1.001) & (ratios.values>=0.999))]

# %%
names = []
dontuse = ['Gowanus Tech Station','8D OPS 01', 'Bressler','GOW Tech Shop']
for idx,elem in enumerate(temp.index):
    name = data[data.startstationid==elem].startstationname.unique()[0]
    print str(idx+1)+")"+name
    if name not in dontuse:
        if (np.intersect1d(name,topstartnames).shape[0]!=0 and np.intersect1d(name,topendnames).shape[0]!=0):
            names.append('~* ' + name)
        elif np.intersect1d(name,topstartnames).shape[0]!=0:
            names.append('~ ' + name)
        elif np.intersect1d(name,topendnames).shape[0]!=0:
            names.append('* ' + name)
        else :
            names.append(name)
    else:
        names.append(name+'(service station)')
print idx
# Out:
# 1)E 32 St & Park Ave
# 2)Allen St & Stanton St
# 3)W 45 St & 8 Ave
# 4)Forsyth St & Broome St
# 5)W 37 St & 10 Ave
# 6)Canal St & Rutgers St
# 7)1 Ave & E 78 St
# 8)E 19 St & 3 Ave
# 9)W 37 St & Broadway
# 10)Lexington Ave & E 63 St
# 11)E 55 St & Lexington Ave
# 12)Riverside Dr & W 82 St
# 13)Harrison St & Hudson St
# 14)E 89 St & 3 Ave
# 15)Avenue D & E 3 St
# 16)West End Ave & W 94 St
# 17)Madison St & Montgomery St
# 18)Metropolitan Ave & Meeker Ave
# 19)Clinton St & Tillary St
# 20)E 91 St & Park Ave
# 21)Bushwick Ave & Powers St
# 22)Central Park West & W 102 St
# 23)S 4 St & Rodney St
# 24)E 88 St & Park Ave
# 25)Union Ave & Jackson St
# 26)Scholes St & Manhattan Ave
# 27)Carlton Ave & Park Ave
# 28)Gowanus Tech Station
# 29)8D OPS 01
# 30)Bressler
# 31)GOW Tech Shop
# 30

# %%
p = figure(x_range = names)
standardize(p)
standardizevbar(p)

x=names
top = temp.values
width = 0.85
bottom = 0
p.vbar(x=x,top=top,width=width,bottom=bottom,color='skyblue');
p.line(x=x,y=np.ones(31), line_width=2)

p.title.text = 'Most Balanced Stations - Equal Starts and Ends'
p.xaxis.axis_label = 'Station Name'
p.yaxis.axis_label = '# trips starting / # trips ending'

p.left[0].formatter.use_scientific = False

# %%
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="7c7b8d02-706e-4fab-be7e-23173077ef8b"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("7c7b8d02-706e-4fab-be7e-23173077ef8b");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("7c7b8d02-706e-4fab-be7e-23173077ef8b");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '7c7b8d02-706e-4fab-be7e-23173077ef8b' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"6814f13b-5226-41a7-8aae-7a409c92c9ef":{"roots":{"references":[{"attributes":{},"id":"81faeed4-ba57-4071-b519-8a4217c91d9d","type":"HelpTool"},{"attributes":{"source":{"id":"987a6274-bbb2-44a7-8bc6-035039a10d9c","type":"ColumnDataSource"}},"id":"eb1f59cf-f052-411f-94ba-6e7d6c361e7e","type":"CDSView"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},
# 941197   NaN        17.0        5.0       11.0      12.0
# 941864   NaN        17.0        5.0       11.0      12.0
# 941894   NaN        17.0        5.0       11.0      12.0
# 942729   NaN        17.0        5.0       12.0      12.0
# 942740   NaN        17.0        5.0       12.0      12.0
# 944032   NaN        17.0        5.0       14.0      14.0
# 944228   NaN        17.0        5.0       14.0      14.0
# 944923  57.0        17.0        5.0       15.0      15.0
# 944941   NaN        17.0        5.0       15.0      15.0
# 944949   NaN        17.0        5.0       15.0      15.0
# 944960   NaN        17.0        5.0       15.0      15.0
# 945005   NaN        17.0        5.0       15.0      15.0
# 946068   NaN        17.0        5.0       15.0      15.0
# 946092   NaN        17.0        5.0       15.0      15.0
# 946099   NaN        17.0        5.0       15.0      15.0
# 946100   NaN        17.0        5.0       15.0      15.0
# 946115   NaN        17.0        5.0       15.0      15.0
# 946181   NaN        17.0        5.0       15.0      15.0
# 946209   NaN        17.0        5.0       15.0      15.0
# 946886   NaN        17.0        5.0       15.0      15.0
# 947433   NaN        17.0        5.0       15.0      16.0
# 947437   NaN        17.0        5.0       15.0      16.0
# 947749  28.0        17.0        5.0       16.0      16.0
# 947761  28.0        17.0        5.0       16.0      16.0
# 947835   NaN        17.0        5.0       16.0      16.0
# 947840   NaN        17.0        5.0       16.0      16.0
# 947925   NaN        17.0        5.0       16.0      16.0
# 947942  30.0        17.0        5.0       16.0      16.0
# 948007  23.0        17.0        5.0       16.0      16.0
# 948070  26.0        17.0        5.0       16.0      16.0
# 948360   NaN        17.0        5.0       16.0      16.0
# 948363   NaN        17.0        5.0       16.0      16.0
# 948582  22.0        17.0        5.0       16.0      16.0
# 948585  22.0        17.0        5.0       16.0      16.0
# 948883   NaN        17.0        5.0       16.0      16.0
# 948889   NaN        17.0        5.0       16.0      16.0
# 948890   NaN        17.0        5.0       16.0      16.0

# %% [markdown]
# ### had to exclude the first 3 stop>>start...they are service stations for citi bike

# %%
temp = ratios[(ratios.values==1)]

# %%
names = []
for idx,elem in enumerate(temp.index):
    name = data[data.startstationid==elem].startstationname.unique()[0]
    print str(idx+1)+")"+name
    if (np.intersect1d(name,topstartnames).shape[0]!=0 and np.intersect1d(name,topendnames).shape[0]!=0):
        names.append('~* ' + name)
    elif np.intersect1d(name,topstartnames).shape[0]!=0:
        names.append('~ ' + name)
    elif np.intersect1d(name,topendnames).shape[0]!=0:
        names.append('* ' + name)
    else :
        names.append(name)
print idx
# Out:
# 1)Forsyth St & Broome St
# 2)E 55 St & Lexington Ave
# 3)Avenue D & E 3 St
# 4)Metropolitan Ave & Meeker Ave
# 5)Clinton St & Tillary St
# 6)Bushwick Ave & Powers St
# 7)E 88 St & Park Ave
# 8)Union Ave & Jackson St
# 9)Scholes St & Manhattan Ave
# 10)Carlton Ave & Park Ave
# 11)Gowanus Tech Station
# 12)8D OPS 01
# 13)Bressler
# 14)GOW Tech Shop
# 13

# %%
dontuse = ['Gowanus Tech Station','8D OPS 01', 'Bressler','GOW Tech Shop']
dontuse = np.array(dontuse)
'Gowanus Tech Station' in dontuse
# Out:
# True
