# %% [markdown]
# # Imports and data loading

# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %% [markdown]
# ### Imports

# %%
exec(open("props.py"))
exec(open("helpers.py"))
from __future__ import division
output_notebook(); #force plots to display inline
# %matplotlib inline
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="66c28a6c-1774-4c60-a707-4a2a07e48344">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ### Load data (only do once and then proceed with analysis!)

# %%
# make sure we are using an updated copy of the file, since jupyter tends to cache notebooks
# %load_ext autoreload
# %autoreload loadData

# takes about 4 mins
# %run loadData.ipynb
# Out:
# There are
# 884
# fake ages
#
# There are
# 192432
# previously unknown ages
#
# Total unknown ages is
# 193316
# out of
# 1731594
# total ages
# for percentage
# 0
# There are
# 0
# fake ages
#
# There are
# 193316
# unknown ages
#
# Total unknown ages is
# 193316
# out of
# 1731594
# total ages
# for percentage
# 0

# %% [markdown]
# # Geographic analysis plots

# %% [markdown]
# ### Generic names so I can refactor here instead of refactoring in each plot

# %%
data = Jun17
month = "June"
numDaysMonth = 30

# %% [markdown]
# ### We'll look for the most frequent stations by their id, then print out the plaintext names for easy identification on a map
#
# This was put onto a google map with pins for START,END,BOTH locations
# https://drive.google.com/open?id=1FCjRkk30qxZ7S7p_1iCFA480_JduYe5i&usp=sharing

# %%
print 'START STATION ID'
print data.startstationid.value_counts(sort=True, dropna=False)
topstart = data.startstationid.value_counts(sort=True, dropna=False)[0:20].index
print 'END STATION ID'
print data.endstationid.value_counts(sort=True, dropna=False)
topend = data.endstationid.value_counts(sort=True, dropna=False)[0:20].index
# print 'START STATION NAME'
# print data.startstationname
# print 'END STATION NAME'
# print data.endstationname
# Out:
# START STATION ID
# 519     16364
# 426     13542
# 497     11703
# 402     11388
# 514     11301
# 435     10889
# 459     10574
# 3255    10497
# 490     10009
# 368      9142
# 281      8981
# 523      8976
# 3002     8968
# 477      8964
# 2006     8403
# 284      8298
# 285      8268
# 151      8063
# 168      8050
# 3263     8048
# 358      7803
# 293      7735
# 382      7700
# 359      7690
# 229      7557
# 379      7549
# 128      7532
# 505      7488
# 444      7445
# 492      7282
#         ...
# 3063      350
# 3127      344
# 3061      327
# 3302      308
# 3044      306
# 119       303
# 3327      295
# 3342      274
# 3456      267
# 2005      264
# 3075      262
# 3352      259
# 3337      250
# 3395      199
# 3340      195
# 3326      178
# 3245      171
# 3394      156
# 3330      139
# 3333      131
# 3257       69
# 3432       59
# 3468       32
# 3474       28
# 3250        6
# 3470        5
# 3036        4
# 3239        4
# 3248        2
# 3040        1
# Name: startstationid, dtype: int64
# END STATION ID
# 519     16089
# 426     14122
# 402     12006
# 497     11991
# 514     11272
# 459     11092
# 435     10993
# 3255    10645
# 368      9314
# 490      9213
# 523      9026
# 3002     9001
# 284      8365
# 168      8297
# 285      8256
# 477      8196
# 151      8084
# 432      8072
# 2006     8070
# 358      8005
# 359      7923
# 382      7721
# 293      7721
# 229      7624
# 128      7543
# 505      7496
# 444      7468
# 3263     7394
# 212      7225
# 281      7176
#         ...
# 3456      259
# 3075      243
# 3340      228
# 3432      218
# 3395      204
# 3326      201
# 3333      185
# 3245      183
# 3394      172
# 3330      163
# 3257       58
# 3468       34
# 3250       32
# 3474       27
# 3267        8
# 3470        5
# 3240        5
# 3184        5
# 3036        4
# 3253        4
# 3239        4
# 3248        3
# 3214        3
# 3186        3
# 3213        2
# 3273        2
# 3183        2
# 3202        1
# 3040        1
# 3185        1
# Name: endstationid, dtype: int64

# %%
print 'START'
topstartnames = []
for idx,elem in enumerate(topstart):
    print str(idx+1)+")"+data[data.startstationid==elem].startstationname.unique()
    topstartnames.append(data[data.startstationid==elem].startstationname.unique()[0])
print idx
# Out:
# START
# ['1)Pershing Square North']
# ['2)West St & Chambers St']
# ['3)E 17 St & Broadway']
# ['4)Broadway & E 22 St']
# ['5)12 Ave & W 40 St']
# ['6)W 21 St & 6 Ave']
# ['7)W 20 St & 11 Ave']
# ['8)8 Ave & W 31 St']
# ['9)8 Ave & W 33 St']
# ['10)Carmine St & 6 Ave']
# ['11)Grand Army Plaza & Central Park S']
# ['12)W 38 St & 8 Ave']
# ['13)South End Ave & Liberty St']
# ['14)W 41 St & 8 Ave']
# ['15)Central Park S & 6 Ave']
# ['16)Greenwich Ave & 8 Ave']
# ['17)Broadway & E 14 St']
# ['18)Cleveland Pl & Spring St']
# ['19)W 18 St & 6 Ave']
# ['20)Cooper Square & E 7 St']
# 19

# %%
print 'END'
topendnames = []
for idx,elem in enumerate(topend):
    print str(idx+1)+")"+data[data.endstationid==elem].endstationname.unique()
    topendnames.append(data[data.endstationid==elem].endstationname.unique()[0])
print idx
# Out:
# END
# ['1)Pershing Square North']
# ['2)West St & Chambers St']
# ['3)Broadway & E 22 St']
# ['4)E 17 St & Broadway']
# ['5)12 Ave & W 40 St']
# ['6)W 20 St & 11 Ave']
# ['7)W 21 St & 6 Ave']
# ['8)8 Ave & W 31 St']
# ['9)Carmine St & 6 Ave']
# ['10)8 Ave & W 33 St']
# ['11)W 38 St & 8 Ave']
# ['12)South End Ave & Liberty St']
# ['13)Greenwich Ave & 8 Ave']
# ['14)W 18 St & 6 Ave']
# ['15)Broadway & E 14 St']
# ['16)W 41 St & 8 Ave']
# ['17)Cleveland Pl & Spring St']
# ['18)E 7 St & Avenue A']
# ['19)Central Park S & 6 Ave']
# ['20)Christopher St & Greenwich St']
# 19

# %%
print 'BOTH'
overlap = np.intersect1d(topstart,topend)
print overlap.size
for idx,elem in enumerate(overlap):
    print data[data.endstationid==elem].endstationname.unique()
    print data[data.startstationid==elem].startstationname.unique()
print idx
# Out:
# BOTH
# 18
# ['Cleveland Pl & Spring St']
# ['Cleveland Pl & Spring St']
# ['W 18 St & 6 Ave']
# ['W 18 St & 6 Ave']
# ['Greenwich Ave & 8 Ave']
# ['Greenwich Ave & 8 Ave']
# ['Broadway & E 14 St']
# ['Broadway & E 14 St']
# ['Carmine St & 6 Ave']
# ['Carmine St & 6 Ave']
# ['Broadway & E 22 St']
# ['Broadway & E 22 St']
# ['West St & Chambers St']
# ['West St & Chambers St']
# ['W 21 St & 6 Ave']
# ['W 21 St & 6 Ave']
# ['W 20 St & 11 Ave']
# ['W 20 St & 11 Ave']
# ['W 41 St & 8 Ave']
# ['W 41 St & 8 Ave']
# ['8 Ave & W 33 St']
# ['8 Ave & W 33 St']
# ['E 17 St & Broadway']
# ['E 17 St & Broadway']
# ['12 Ave & W 40 St']
# ['12 Ave & W 40 St']
# ['Pershing Square North']
# ['Pershing Square North']
# ['W 38 St & 8 Ave']
# ['W 38 St & 8 Ave']
# ['Central Park S & 6 Ave']
# ['Central Park S & 6 Ave']
# ['South End Ave & Liberty St']
# ['South End Ave & Liberty St']
# ['8 Ave & W 31 St']
# ['8 Ave & W 31 St']
# 17

# %% [markdown]
# ### Start stations histogram

# %%
p = figure(x_range = topstartnames)
standardize(p)
standardizevbar(p)

x=topstartnames
temp = data[data.startstationid.isin(topstart)]
temp = temp.groupby('startstationid').count().max(1).values
temp = np.sort(temp)
temp = temp[::-1] # to sort in descending order
top = temp
width = 0.85
bottom = 0
p.vbar(x=x,top=top,width=width,bottom=bottom,color='skyblue');

pcts = top/data.shape[0]*100
pcts = np.round(pcts,2)
pctsStrings = []
for i in range(pcts.size):
    pctsStrings.append(str(pcts[i]) + "%")
source = ColumnDataSource(data=dict(x=x,
                                   top=top,
                                   pcts=pctsStrings))
labels = LabelSet(x='x',y='top',text='pcts',
                 level='glyph',x_offset=0,y_offset=5,
                 source=source,render_mode='canvas',
                 text_align='center',text_font_size='7pt',angle=-0.5)
p.add_layout(labels)
print(str(sum(pcts)) + '% of trips originated at these stations')

p.title.text = 'Trips Taken From Top 20 Origin Stations'
p.xaxis.axis_label = 'Station Name'
p.yaxis.axis_label = '# of trips'

p.left[0].formatter.use_scientific = False
# Out:
# 11.6% of trips originated at these stations

# %%
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="d664f6fc-2842-456b-9edd-36b4d2bf089c"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("d664f6fc-2842-456b-9edd-36b4d2bf089c");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("d664f6fc-2842-456b-9edd-36b4d2bf089c");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'd664f6fc-2842-456b-9edd-36b4d2bf089c' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"6cc407f1-e542-49f0-8e8f-89642edce083":{"roots":{"references":[{"attributes":{"callback":null,"start":0},"id":"f2cdc380-f7f7-4167-a214-d23a6dd6d4de","type":"DataRange1d"},{"attributes":{},"id":"307e9fa9-db15-482a-8ec8-1a3263d0acbd","type":"WheelZoomTool"},{"attributes":{},"id":"1d0db2f6-5c80-47a0-ac07-f86eb838443a","type":"CategoricalTicker"},{"attributes":{},"id":"22f5a08a-d1bc-4039-a5ce-7566aa61178b","type":"LinearScale"},{"attributes":{"fill_color":{"value":"skyblue"},"line_color":{"value":"skyblue"},"top":{"field":"top"},"width":{"value":0.85},"x":{"field":"x"}},"id":"664a784b-94ae-445a-a9b0-006fdba5ec3d","type":"VBar"},{"attributes":{},"id":"56ca2963-73d9-4e71-9b36-3ffc4bf06569","type":"CategoricalScale"},{"attributes":{"callback":null,"column_names":["x","top"],"data":{"top":[16364,13542,11703,11388,11301,10889,10574,10497,10009,9142,8981,8976,8968,8964,8403,8298,8268,8063,8050,8048],"x":["Pershing Square North","West St & Chambers St","E 17 St & Broadway","Broadway & E 22 St","12 Ave & W 40 St","W 21 St & 6 Ave","W 20 St & 11 Ave","8 Ave & W 31 St","8 Ave & W 33 St","Carmine St & 6 Ave","Grand Army Plaza & Central Park S","W 38 St & 8 Ave","South End Ave & Liberty St","W 41 St & 8 Ave","Central Park S & 6 Ave","Greenwich Ave & 8 Ave","Broadway & E 14 St","Cleveland Pl & Spring St","W 18 St & 6 Ave","Cooper Square & E 7 St"]}},"id":"97de6956-e2bf-4a17-93c5-3eb76caf7a51","type":"ColumnDataSource"},{"attributes":{},"id":"ed59182e-cd1a-4c41-9891-5d0d325bf635","type":"PanTool"},{"attributes":{"use_scientific":false},"id":"2e967079-1d8f-4394-8544-ecb6d9f85911","type":"BasicTickFormatter"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"ed59182e-cd1a-4c41-9891-5d0d325bf635","type":"PanTool"},{"id":"307e9fa9-db15-482a-8ec8-1a3263d0acbd","type":"WheelZoomTool"},{"id":"00a6f72b-2c61-456d-b8bd-b0d29e907b63","type":"BoxZoomTool"},{"id":"546cf584-a996-4179-a7a2-87d317d32a20","type":"SaveTool"},{"id":"f92deed1-d1e5-4654-b586-1af22bb73812","type":"ResetTool"},{"id":"26a22921-adc2-4b17-bbb3-61759066b482","type":"HelpTool"}]},"id":"d19a9dda-95d9-4b46-b661-d05e3edead9c","type":"Toolbar"},{"attributes":{},"id":"f92deed1-d1e5-4654-b586-1af22bb73812","type":"ResetTool"},{"attributes":{"grid_line_color":{"value":null},"plot":{"id":"1599ff00-4be5-4d34-a8f0-a38fb158f536","subtype":"Figure","type":"Plot"},"ticker":{"id":"1d0db2f6-5c80-47a0-ac07-f86eb838443a","type":"CategoricalTicker"}},"id":"14e64399-5129-402f-89c9-d53085d23cee","type":"Grid"},{"attributes":{"angle":{"units":"rad","value":-0.5},"level":"glyph","plot":{"id":"1599ff00-4be5-4d34-a8f0-a38fb158f536","subtype":"Figure","type":"Plot"},"source":{"id":"6a144b06-3ffb-4fa2-b5e2-22ad3f649dbd","type":"ColumnDataSource"},"text":{"field":"pcts"},"text_align":"center","text_font_size":{"value":"7pt"},"x":{"field":"x"},"y":{"field":"top"},"y_offset":{"value":5}},"id":"c098d1f1-caf8-47bf-a7bc-5473b290e3b8","type":"LabelSet"},{"attributes":{"axis_label":"Station Name","axis_label_text_font_size":{"value":"14pt"},"formatter":{"id":"3669cce4-aa8d-4489-8d10-c4f6ad4f68b8","type":"CategoricalTickFormatter"},"major_label_orientation":-0.75,"major_label_text_font_size":{"value":"9pt"},"minor_tick_line_color":{"value":null},"plot":{"id":"1599ff00-4be5-4d34-a8f0-a38fb158f536","subtype":"Figure","type":"Plot"},"ticker":{"id":"1d0db2f6-5c80-47a0-ac07-f86eb838443a","type":"CategoricalTicker"}},"id":"df77e389-cde8-46ec-8a96-c9a01df73a96","type":"CategoricalAxis"},{"attributes":{"align":"center","plot":null,"text":"Trips Taken From Top 20 Origin Stations","text_font_size":{"value":"16pt"}},"id":"be0505e5-0a7d-4313-b65d-133303346046","type":"Title"},{"attributes":{"below":[{"id":"df77e389-cde8-46ec-8a96-c9a01df73a96","type":"CategoricalAxis"}],"left":[{"id":"e2a65335-db04-44e9-92b6-0716aa3a9769","type":"LinearAxis"}],"renderers":[{"id":"df77e389-cde8-46ec-8a96-c9a01df73a96","type":"CategoricalAxis"},{"id":"14e64 ...

# %% [markdown]
# ### End stations histogram

# %%
p = figure(x_range = topendnames)
standardize(p)
standardizevbar(p)

x=topendnames
temp = data[data.endstationid.isin(topend)]
temp = temp.groupby('endstationid').count().max(1).values
temp = np.sort(temp)
temp = temp[::-1] # to sort in descending order
top = temp
width = 0.85
bottom = 0
p.vbar(x=x,top=top,width=width,bottom=bottom,color='skyblue');

pcts = top/data.shape[0]*100
pcts = np.round(pcts,2)
pctsStrings = []
for i in range(pcts.size):
    pctsStrings.append(str(pcts[i]) + "%")
source = ColumnDataSource(data=dict(x=x,
                                   top=top,
                                   pcts=pctsStrings))
labels = LabelSet(x='x',y='top',text='pcts',
                 level='glyph',x_offset=0,y_offset=5,
                 source=source,render_mode='canvas',
                 text_align='center',text_font_size='7pt',angle=-0.5)
p.add_layout(labels)
print(str(sum(pcts))+ '% of trips ended at these stations')

p.title.text = 'Trips Taken From Top 20 Destination Stations'
p.xaxis.axis_label = 'Station Name'
p.yaxis.axis_label = '# of trips'

p.left[0].formatter.use_scientific = False
# Out:
# 11.55% of trips ended at these stations

# %%
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="db133707-8bfc-49a4-a033-354c23c15b75"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("db133707-8bfc-49a4-a033-354c23c15b75");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("db133707-8bfc-49a4-a033-354c23c15b75");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'db133707-8bfc-49a4-a033-354c23c15b75' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"d5f292ef-d528-4a71-97cf-e54032af969d":{"roots":{"references":[{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"top":{"field":"top"},"width":{"value":0.85},"x":{"field":"x"}},"id":"850e8119-32fe-4cbe-af4e-3ecd073864d9","type":"VBar"},{"attributes":{},"id":"18459a62-6214-4847-81b7-2af74cfa5428","type":"ResetTool"},{"attributes":{"dimension":1,"plot":{"id":"ec0b7031-c99a-4cdf-823b-8d902bddb3c8","subtype":"Figure","type":"Plot"},"ticker":{"id":"94fa72fe-9a0b-484a-ac76-dba757c71e1c","type":"BasicTicker"}},"id":"28736c76-a28e-4481-9891-4e8713082ab3","type":"Grid"},{"attributes":{},"id":"2b0acdca-c079-483e-9dc8-93637f57ce26","type":"LinearScale"},{"attributes":{"use_scientific":false},"id":"62c1d620-d7dc-4743-87e9-d036931ad440","type":"BasicTickFormatter"},{"attributes":{"callback":null,"start":0},"id":"e3d8d8eb-fe63-423b-ab2c-e2f06caf2864","type":"DataRange1d"},{"attributes":{"fill_color":{"value":"skyblue"},"line_color":{"value":"skyblue"},"top":{"field":"top"},"width":{"value":0.85},"x":{"field":"x"}},"id":"88115bdd-6329-42a5-8b84-d03107466c7f","type":"VBar"},{"attributes":{"overlay":{"id":"e0474391-e5f5-4ce1-b323-1c54a022375b","type":"BoxAnnotation"}},"id":"21fe436c-147a-4800-9c43-d52b7ce87228","type":"BoxZoomTool"},{"attributes":{"axis_label":"Station Name","axis_label_text_font_size":{"value":"14pt"},"formatter":{"id":"37170395-9946-4a42-8006-a87234dd5950","type":"CategoricalTickFormatter"},"major_label_orientation":-0.75,"major_label_text_font_size":{"value":"9pt"},"minor_tick_line_color":{"value":null},"plot":{"id":"ec0b7031-c99a-4cdf-823b-8d902bddb3c8","subtype":"Figure","type":"Plot"},"ticker":{"id":"47f1a74b-84a2-4a96-9da4-bc494b306d6a","type":"CategoricalTicker"}},"id":"c75b389b-6a17-4445-b12b-e1d8e6c4c3f6","type":"CategoricalAxis"},{"attributes":{},"id":"04db5d91-fb65-4a28-ae57-7402bc2c4acc","type":"CategoricalScale"},{"attributes":{"callback":null,"column_names":["x","top"],"data":{"top":[16089,14122,12006,11991,11272,11092,10993,10645,9314,9213,9026,9001,8365,8297,8256,8196,8084,8072,8070,8005],"x":["Pershing Square North","West St & Chambers St","Broadway & E 22 St","E 17 St & Broadway","12 Ave & W 40 St","W 20 St & 11 Ave","W 21 St & 6 Ave","8 Ave & W 31 St","Carmine St & 6 Ave","8 Ave & W 33 St","W 38 St & 8 Ave","South End Ave & Liberty St","Greenwich Ave & 8 Ave","W 18 St & 6 Ave","Broadway & E 14 St","W 41 St & 8 Ave","Cleveland Pl & Spring St","E 7 St & Avenue A","Central Park S & 6 Ave","Christopher St & Greenwich St"]}},"id":"51221ac4-6249-4a66-bc92-98271ce1ea6a","type":"ColumnDataSource"},{"attributes":{},"id":"37170395-9946-4a42-8006-a87234dd5950","type":"CategoricalTickFormatter"},{"attributes":{},"id":"1f2bceda-7520-49df-947b-1d5a1465fe61","type":"PanTool"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"1f2bceda-7520-49df-947b-1d5a1465fe61","type":"PanTool"},{"id":"e84210a8-3029-4269-9f51-070d003a5e7f","type":"WheelZoomTool"},{"id":"21fe436c-147a-4800-9c43-d52b7ce87228","type":"BoxZoomTool"},{"id":"21dae627-8cc3-4ed7-8022-ccf839b34290","type":"SaveTool"},{"id":"18459a62-6214-4847-81b7-2af74cfa5428","type":"ResetTool"},{"id":"ce935e1d-4191-4487-a8d6-d47818ab9bd2","type":"HelpTool"}]},"id":"3b65c002-5b9a-4d4f-98a0-388e796d3de2","type":"Toolbar"},{"attributes":{"axis_label":"# of trips","axis_label_text_font_size":{"value":"14pt"},"formatter":{"id":"62c1d620-d7dc-4743-87e9-d036931ad440","type":"BasicTickFormatter"},"major_label_text_font_size":{"value":"9pt"},"plot":{"id":"ec0b7031-c99a-4cdf-823b-8d902bddb3c8","subtype":"Figure","type":"Plot"},"ticker":{"id":"94fa72fe-9a0b-484a-ac76-dba757c71e1c","type":"BasicTicker"}},"id":"c6fe7dd2-15fe-46c2-a3b0-2fa70c462c9d","type":"LinearAxis"},{"attributes":{},"id":"47f1a74b-84a2-4a96-9da4-bc494b306d6a","type":"CategoricalTicker"},{"attributes":{"bottom_units":"screen","fill_alpha":{" ...

# %% [markdown]
# # Other stuff to plot
# - most imbalanced stations (ratio btwn origin/dest)
# - heatmap of all ratios of balance (symmetric matrix)
#     - to make it a PGM...represent each station as a node and draw weighted lines between?...
# - DONE most pop dest for each of the popular origin
# - DONE most pop origin for each of the popular dest
# - most pop dest/orig for subscriber/customer

# %% [markdown]
# # Learning
# - learn destination station from origin station
#     - may be easier to have binary choice (i.e. central park vs not central park
# - learn destination station from origin station and type of rider

# %% [markdown]
# ### Most popular destination for each of the top 20 origin stations
# - find the most used destinations from those top 20 origins
# - how many of those destinations are in the overall top 20 destinations?

# %%
temp = data[data.startstationid.isin(topstart)]
topdests = temp.groupby('endstationid').count().max(1).sort_values(ascending=False)[0:20]

# %%
topdestnames = []
for idx,elem in enumerate(topdests.index):
    name = data[data.endstationid==elem].endstationname.unique()[0]
    print str(idx+1)+")"+name
    if np.intersect1d(name,topendnames).shape[0]==0:
        topdestnames.append(name)
    else :
        topdestnames.append('* '+name)
print idx
topdestnames
# Out:
# 1)West St & Chambers St
# 2)Pershing Square North
# 3)12 Ave & W 40 St
# 4)W 20 St & 11 Ave
# 5)Broadway & E 22 St
# 6)W 21 St & 6 Ave
# 7)9 Ave & W 22 St
# 8)E 17 St & Broadway
# 9)Christopher St & Greenwich St
# 10)Carmine St & 6 Ave
# 11)6 Ave & W 33 St
# 12)W 22 St & 10 Ave
# 13)W 16 St & The High Line
# 14)Pier 40 - Hudson River Park
# 15)8 Ave & W 31 St
# 16)W 38 St & 8 Ave
# 17)Central Park S & 6 Ave
# 18)Washington St & Gansevoort St
# 19)E 7 St & Avenue A
# 20)W 22 St & 8 Ave
# 19
# ['~ West St & Chambers St',
#  '~ Pershing Square North',
#  '~ 12 Ave & W 40 St',
#  '~ W 20 St & 11 Ave',
#  '~ Broadway & E 22 St',
#  '~ W 21 St & 6 Ave',
#  '9 Ave & W 22 St',
#  '~ E 17 St & Broadway',
#  '~ Christopher St & Greenwich St',
#  '~ Carmine St & 6 Ave',
#  '6 Ave & W 33 St',
#  'W 22 St & 10 Ave',
#  'W 16 St & The High Line',
#  'Pier 40 - Hudson River Park',
#  '~ 8 Ave & W 31 St',
#  '~ W 38 St & 8 Ave',
#  '~ Central Park S & 6 Ave',
#  'Washington St & Gansevoort St',
#  '~ E 7 St & Avenue A',
#  'W 22 St & 8 Ave']

# %%
p = figure(x_range = topdestnames)
standardize(p)
standardizevbar(p)

x=topdestnames
top = topdests.values
width = 0.85
bottom = 0
p.vbar(x=x,top=top,width=width,bottom=bottom,color='skyblue');

pcts = top/data.shape[0]*100
pcts = np.round(pcts,2)
pctsStrings = []
for i in range(pcts.size):
    pctsStrings.append(str(pcts[i]) + "%")
source = ColumnDataSource(data=dict(x=x,
                                   top=top,
                                   pcts=pctsStrings))
labels = LabelSet(x='x',y='top',text='pcts',
                 level='glyph',x_offset=0,y_offset=5,
                 source=source,render_mode='canvas',
                 text_align='center',text_font_size='7pt',angle=-0.5)
p.add_layout(labels)
print(str(sum(pcts)) + '% of total trips ended at these stations')
print(str(sum(topdests.values/temp.shape[0])*100) + '% of trips taken from the top 20 stations ended at these stations')

p.title.text = 'Top 20 Destinations of Trips Taken From Top 20 Origin Stations'
p.xaxis.axis_label = 'Station Name'
p.yaxis.axis_label = '# of trips'

p.left[0].formatter.use_scientific = False
# Out:
# 2.04% of total trips ended at these stations
# 17.664198615% of trips taken from the top 20 stations ended at these stations

# %%
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="51280bd2-e75c-441c-b85e-7b882abfb0f2"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("51280bd2-e75c-441c-b85e-7b882abfb0f2");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("51280bd2-e75c-441c-b85e-7b882abfb0f2");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '51280bd2-e75c-441c-b85e-7b882abfb0f2' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"dcba8cb4-864b-43c2-aefb-86d92db8ad25":{"roots":{"references":[{"attributes":{},"id":"d353ac0f-11a5-4ec4-be4e-a79e7cf18dd1","type":"ResetTool"},{"attributes":{},"id":"2a79213f-4337-4400-a6dc-bf0de57cf99c","type":"SaveTool"},{"attributes":{},"id":"7a742318-d301-4372-8ba5-75396416327e","type":"WheelZoomTool"},{"attributes":{"callback":null,"start":0},"id":"55748999-d054-4763-b314-b982a4568511","type":"DataRange1d"},{"attributes":{},"id":"13eea9f0-9ce1-49e0-bbf3-af5abec86aac","type":"CategoricalTicker"},{"attributes":{"angle":{"units":"rad","value":-0.5},"level":"glyph","plot":{"id":"199c0e9d-d9ca-40b4-9f1b-66ec6b458dd2","subtype":"Figure","type":"Plot"},"source":{"id":"9dc87614-0f0c-48e2-bf56-9feb73ffbdb2","type":"ColumnDataSource"},"text":{"field":"pcts"},"text_align":"center","text_font_size":{"value":"7pt"},"x":{"field":"x"},"y":{"field":"top"},"y_offset":{"value":5}},"id":"5e68f9c4-e0e9-4cf3-8f6f-032fd8f383cc","type":"LabelSet"},{"attributes":{"callback":null,"factors":["~ West St & Chambers St","~ Pershing Square North","~ 12 Ave & W 40 St","~ W 20 St & 11 Ave","~ Broadway & E 22 St","~ W 21 St & 6 Ave","9 Ave & W 22 St","~ E 17 St & Broadway","~ Christopher St & Greenwich St","~ Carmine St & 6 Ave","6 Ave & W 33 St","W 22 St & 10 Ave","W 16 St & The High Line","Pier 40 - Hudson River Park","~ 8 Ave & W 31 St","~ W 38 St & 8 Ave","~ Central Park S & 6 Ave","Washington St & Gansevoort St","~ E 7 St & Avenue A","W 22 St & 8 Ave"]},"id":"b8b66f5c-0da4-4ab8-9e2b-247dcd9aa380","type":"FactorRange"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"top":{"field":"top"},"width":{"value":0.85},"x":{"field":"x"}},"id":"72bd0f77-b14d-471f-97ae-f414506d3e44","type":"VBar"},{"attributes":{"callback":null,"column_names":["x","top"],"data":{"top":[2804,2322,2291,2280,1986,1914,1892,1797,1601,1585,1549,1544,1515,1513,1504,1487,1482,1482,1468,1388],"x":["~ West St & Chambers St","~ Pershing Square North","~ 12 Ave & W 40 St","~ W 20 St & 11 Ave","~ Broadway & E 22 St","~ W 21 St & 6 Ave","9 Ave & W 22 St","~ E 17 St & Broadway","~ Christopher St & Greenwich St","~ Carmine St & 6 Ave","6 Ave & W 33 St","W 22 St & 10 Ave","W 16 St & The High Line","Pier 40 - Hudson River Park","~ 8 Ave & W 31 St","~ W 38 St & 8 Ave","~ Central Park S & 6 Ave","Washington St & Gansevoort St","~ E 7 St & Avenue A","W 22 St & 8 Ave"]}},"id":"5826561d-fb6a-4c8b-9683-dd43737425aa","type":"ColumnDataSource"},{"attributes":{},"id":"40250052-872d-40b0-9eb5-65e19c2adaa6","type":"LinearScale"},{"attributes":{"grid_line_color":{"value":null},"plot":{"id":"199c0e9d-d9ca-40b4-9f1b-66ec6b458dd2","subtype":"Figure","type":"Plot"},"ticker":{"id":"13eea9f0-9ce1-49e0-bbf3-af5abec86aac","type":"CategoricalTicker"}},"id":"54f835c1-774a-4017-9644-a1913c8a6ea0","type":"Grid"},{"attributes":{"callback":null,"column_names":["pcts","x","top"],"data":{"pcts":["0.16%","0.13%","0.13%","0.13%","0.11%","0.11%","0.11%","0.1%","0.09%","0.09%","0.09%","0.09%","0.09%","0.09%","0.09%","0.09%","0.09%","0.09%","0.08%","0.08%"],"top":[2804,2322,2291,2280,1986,1914,1892,1797,1601,1585,1549,1544,1515,1513,1504,1487,1482,1482,1468,1388],"x":["~ West St & Chambers St","~ Pershing Square North","~ 12 Ave & W 40 St","~ W 20 St & 11 Ave","~ Broadway & E 22 St","~ W 21 St & 6 Ave","9 Ave & W 22 St","~ E 17 St & Broadway","~ Christopher St & Greenwich St","~ Carmine St & 6 Ave","6 Ave & W 33 St","W 22 St & 10 Ave","W 16 St & The High Line","Pier 40 - Hudson River Park","~ 8 Ave & W 31 St","~ W 38 St & 8 Ave","~ Central Park S & 6 Ave","Washington St & Gansevoort St","~ E 7 St & Avenue A","W 22 St & 8 Ave"]}},"id":"9dc87614-0f0c-48e2-bf56-9feb73ffbdb2","type":"ColumnDataSource"},{"attributes":{},"id":"d03f193e-c146-46bc-8d8d-6cb577badb54","type":"HelpTool"},{"attributes":{"overlay":{"id":"ec9413a2-1a08-4f20-b7cc-5503bbf1657e","type":"BoxAnnotation"}},"id":"826b75cd-4c1c-46b6-af7f-36d0a9ce22b1 ...

# %% [markdown]
# ### Most popular origin for each of the top 20 end stations
# - find the most used origins from those top 20 destinations
# - how many of those origins are in the overall top 20 starts?

# %%
temp = data[data.endstationid.isin(topend)]
toporigins = temp.groupby('startstationid').count().max(1).sort_values(ascending=False)[0:20]

# %%
toporiginnames = []
for idx,elem in enumerate(toporigins.index):
    name = data[data.startstationid==elem].startstationname.unique()[0]
    print str(idx+1)+")"+name
    if np.intersect1d(name,topstartnames).shape[0]==0:
        toporiginnames.append(name)
    else :
        toporiginnames.append('~ '+name)
print idx
toporiginnames
# Out:
# 1)West St & Chambers St
# 2)12 Ave & W 40 St
# 3)W 20 St & 11 Ave
# 4)Pershing Square North
# 5)Broadway & E 22 St
# 6)E 17 St & Broadway
# 7)8 Ave & W 16 St
# 8)W 21 St & 6 Ave
# 9)Washington St & Gansevoort St
# 10)9 Ave & W 22 St
# 11)Greenwich Ave & 8 Ave
# 12)Pier 40 - Hudson River Park
# 13)Carmine St & 6 Ave
# 14)Lafayette St & E 8 St
# 15)Cooper Square & E 7 St
# 16)Christopher St & Greenwich St
# 17)South End Ave & Liberty St
# 18)W 13 St & Hudson St
# 19)W 16 St & The High Line
# 20)W 22 St & 10 Ave
# 19
# ['~ West St & Chambers St',
#  '~ 12 Ave & W 40 St',
#  '~ W 20 St & 11 Ave',
#  '~ Pershing Square North',
#  '~ Broadway & E 22 St',
#  '~ E 17 St & Broadway',
#  '8 Ave & W 16 St',
#  '~ W 21 St & 6 Ave',
#  'Washington St & Gansevoort St',
#  '9 Ave & W 22 St',
#  '~ Greenwich Ave & 8 Ave',
#  'Pier 40 - Hudson River Park',
#  '~ Carmine St & 6 Ave',
#  'Lafayette St & E 8 St',
#  '~ Cooper Square & E 7 St',
#  'Christopher St & Greenwich St',
#  '~ South End Ave & Liberty St',
#  'W 13 St & Hudson St',
#  'W 16 St & The High Line',
#  'W 22 St & 10 Ave']

# %%
p = figure(x_range = toporiginnames)
standardize(p)
standardizevbar(p)

x=toporiginnames
top = toporigins.values
width = 0.85
bottom = 0
p.vbar(x=x,top=top,width=width,bottom=bottom,color='skyblue');

pcts = top/data.shape[0]*100
pcts = np.round(pcts,2)
pctsStrings = []
for i in range(pcts.size):
    pctsStrings.append(str(pcts[i]) + "%")
source = ColumnDataSource(data=dict(x=x,
                                   top=top,
                                   pcts=pctsStrings))
labels = LabelSet(x='x',y='top',text='pcts',
                 level='glyph',x_offset=0,y_offset=5,
                 source=source,render_mode='canvas',
                 text_align='center',text_font_size='7pt',angle=-0.5)
p.add_layout(labels)
print(str(sum(pcts)) + '% of total trips started at these stations')
print(str(sum(toporigins.values/temp.shape[0])*100) + '% of trips ending at the top 20 stations started at these stations')

p.title.text = 'Top 20 Origins of Trips Taken From Top 20 Destination Stations'
p.xaxis.axis_label = 'Station Name'
p.yaxis.axis_label = '# of trips'

p.left[0].formatter.use_scientific = False
# Out:
# 2.15% of total trips started at these stations
# 18.5593851351% of trips ending at the top 20 stations started at these stations

# %%
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="bdea305a-915d-4db1-9de3-a72176088676"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("bdea305a-915d-4db1-9de3-a72176088676");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("bdea305a-915d-4db1-9de3-a72176088676");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'bdea305a-915d-4db1-9de3-a72176088676' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"237ce365-3349-4f42-b230-003e03a22c0a":{"roots":{"references":[{"attributes":{},"id":"0699eef2-ccc3-4eb1-9269-7520666eccb3","type":"HelpTool"},{"attributes":{"use_scientific":false},"id":"957ceba2-210f-4278-be13-060df4f41e0b","type":"BasicTickFormatter"},{"attributes":{"angle":{"units":"rad","value":-0.5},"level":"glyph","plot":{"id":"b8a071c3-a63a-4ef2-931e-94a56f344296","subtype":"Figure","type":"Plot"},"source":{"id":"d76f0d09-83fc-4442-8741-b5d64b8aaf78","type":"ColumnDataSource"},"text":{"field":"pcts"},"text_align":"center","text_font_size":{"value":"7pt"},"x":{"field":"x"},"y":{"field":"top"},"y_offset":{"value":5}},"id":"4439f54d-ecb0-4ef7-9fd6-ddf5113aae92","type":"LabelSet"},{"attributes":{"callback":null,"factors":["~ West St & Chambers St","~ 12 Ave & W 40 St","~ W 20 St & 11 Ave","~ Pershing Square North","~ Broadway & E 22 St","~ E 17 St & Broadway","8 Ave & W 16 St","~ W 21 St & 6 Ave","Washington St & Gansevoort St","9 Ave & W 22 St","~ Greenwich Ave & 8 Ave","Pier 40 - Hudson River Park","~ Carmine St & 6 Ave","Lafayette St & E 8 St","~ Cooper Square & E 7 St","Christopher St & Greenwich St","~ South End Ave & Liberty St","W 13 St & Hudson St","W 16 St & The High Line","W 22 St & 10 Ave"]},"id":"a0f28653-4824-443e-ae3c-134cc82b9d16","type":"FactorRange"},{"attributes":{"below":[{"id":"551e5ff9-0f75-4cf0-9147-6d5309dc18d6","type":"CategoricalAxis"}],"left":[{"id":"c8ddc092-13cf-463f-868f-921b33909887","type":"LinearAxis"}],"renderers":[{"id":"551e5ff9-0f75-4cf0-9147-6d5309dc18d6","type":"CategoricalAxis"},{"id":"71ae906d-2f99-4445-9d52-dbb941bd42e9","type":"Grid"},{"id":"c8ddc092-13cf-463f-868f-921b33909887","type":"LinearAxis"},{"id":"e65be519-ac05-4186-941d-689c9db4216a","type":"Grid"},{"id":"e3bcb72e-05a7-4e0a-8dd8-6d1aa94b9db2","type":"BoxAnnotation"},{"id":"eadefe0d-9ab1-4136-b95e-3131205a542b","type":"GlyphRenderer"},{"id":"4439f54d-ecb0-4ef7-9fd6-ddf5113aae92","type":"LabelSet"}],"title":{"id":"c950f713-acf0-412f-80b4-087104bd015d","type":"Title"},"toolbar":{"id":"79a0bf09-7f7e-4261-bb95-14be909a930d","type":"Toolbar"},"x_range":{"id":"a0f28653-4824-443e-ae3c-134cc82b9d16","type":"FactorRange"},"x_scale":{"id":"e354d130-47b2-4be4-826a-00d8a60bb429","type":"CategoricalScale"},"y_range":{"id":"22500cd7-b514-4f8a-a3db-e986ef1c50aa","type":"DataRange1d"},"y_scale":{"id":"095dc10f-63a8-4558-8cbc-9c1929fe5f41","type":"LinearScale"}},"id":"b8a071c3-a63a-4ef2-931e-94a56f344296","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"e354d130-47b2-4be4-826a-00d8a60bb429","type":"CategoricalScale"},{"attributes":{"overlay":{"id":"e3bcb72e-05a7-4e0a-8dd8-6d1aa94b9db2","type":"BoxAnnotation"}},"id":"3cd2eaf7-6dad-4b58-8f3b-3381a6f85374","type":"BoxZoomTool"},{"attributes":{},"id":"095dc10f-63a8-4558-8cbc-9c1929fe5f41","type":"LinearScale"},{"attributes":{"source":{"id":"0db82042-c3c0-410e-90b1-a5f0732bd933","type":"ColumnDataSource"}},"id":"b78117cb-d34b-4788-a9c0-832d85a2910d","type":"CDSView"},{"attributes":{},"id":"71716469-3399-4bb0-bc87-9f7e96540e2f","type":"CategoricalTicker"},{"attributes":{"axis_label":"# of trips","axis_label_text_font_size":{"value":"14pt"},"formatter":{"id":"957ceba2-210f-4278-be13-060df4f41e0b","type":"BasicTickFormatter"},"major_label_text_font_size":{"value":"9pt"},"plot":{"id":"b8a071c3-a63a-4ef2-931e-94a56f344296","subtype":"Figure","type":"Plot"},"ticker":{"id":"e5e44566-66c2-47b6-8c48-83190291f1fd","type":"BasicTicker"}},"id":"c8ddc092-13cf-463f-868f-921b33909887","type":"LinearAxis"},{"attributes":{},"id":"edc7d57b-d5f9-48ac-b213-ea749e32d4aa","type":"CategoricalTickFormatter"},{"attributes":{"align":"center","plot":null,"text":"Top 20 Origins of Trips Taken From Top 20 Destination Stations","text_font_size":{"value":"16pt"}},"id":"c950f713-acf0-412f-80b4-087104bd015d","type":"Title"},{"attributes":{"callback":null,"column_names":["pcts","x","top"],"data":{"pcts":["0.17%","0.14%","0.14%","0.13%","0.12%","0.11%","0.11%","0.11%","0.1%","0.1%","0.1%","0. ...

# %% [markdown]
# ### Most popular station for each type of customer
# For this analysis, we will not distinguish between start/end...just if a station was used or not
#
# ** NOTE:  this means the same trip may be counted twice!  that's fine, just don't compare to other hists **
#
# ** KEY **
#
# ~ = in top 20 start stations
#
# \* = in top 20 end stations
#
# ~\* = in both

# %%
subscribers = data[data.usertype==1]
customers = data[data.usertype==2]
unknowns = data[data.usertype==0]

print subscribers.shape[0]
print customers.shape[0]
print unknowns.shape[0]
# Out:
# 1516952
# 214642
# 0

# %% [markdown]
# #### For subscribers

# %%
ss = subscribers.groupby('startstationid').count().max(1).sort_values(ascending=False)[0:20]
se = subscribers.groupby('endstationid').count().max(1).sort_values(ascending=False)[0:20]

allPoss = np.union1d(ss.index,se.index)
totals = pd.Series(index=allPoss)
for idx,elem in enumerate(allPoss):
    try:
        a = ss.loc[elem]
    except:
        a=0
    try:
        b = se.loc[elem]
    except:
        b=0
    totals.loc[elem] = a+b
totals = totals.sort_values(ascending=False)
print totals.shape
totals
# Out:
# (23L,)
# 519     30551.0
# 402     21972.0
# 497     21706.0
# 426     21451.0
# 435     20877.0
# 3255    19756.0
# 459     18337.0
# 490     17735.0
# 523     16872.0
# 368     16448.0
# 477     16030.0
# 514     15752.0
# 168     15484.0
# 284     15418.0
# 285     15146.0
# 359     15088.0
# 382     14369.0
# 432      7685.0
# 3263     7509.0
# 3002     7272.0
# 293      7206.0
# 229      7184.0
# 379      7176.0
# dtype: float64

# %%
toptotalnames = []
for idx,elem in enumerate(totals.index):
    name = data[data.startstationid==elem].startstationname.unique()[0]
    print str(idx+1)+")"+name
    if (np.intersect1d(name,topstartnames).shape[0]!=0 and np.intersect1d(name,topendnames).shape[0]!=0):
        toptotalnames.append('~* ' + name)
    elif np.intersect1d(name,topstartnames).shape[0]!=0:
        toptotalnames.append('~ ' + name)
    elif np.intersect1d(name,topendnames).shape[0]!=0:
        toptotalnames.append('* ' + name)
    else :
        toptotalnames.append(name)
print idx
toptotalnames
# Out:
# 1)Pershing Square North
# 2)Broadway & E 22 St
# 3)E 17 St & Broadway
# 4)West St & Chambers St
# 5)W 21 St & 6 Ave
# 6)8 Ave & W 31 St
# 7)W 20 St & 11 Ave
# 8)8 Ave & W 33 St
# 9)W 38 St & 8 Ave
# 10)Carmine St & 6 Ave
# 11)W 41 St & 8 Ave
# 12)12 Ave & W 40 St
# 13)W 18 St & 6 Ave
# 14)Greenwich Ave & 8 Ave
# 15)Broadway & E 14 St
# 16)E 47 St & Park Ave
# 17)University Pl & E 14 St
# 18)E 7 St & Avenue A
# 19)Cooper Square & E 7 St
# 20)South End Ave & Liberty St
# 21)Lafayette St & E 8 St
# 22)Great Jones St
# 23)W 31 St & 7 Ave
# 22
# ['~* Pershing Square North',
#  '~* Broadway & E 22 St',
#  '~* E 17 St & Broadway',
#  '~* West St & Chambers St',
#  '~* W 21 St & 6 Ave',
#  '~* 8 Ave & W 31 St',
#  '~* W 20 St & 11 Ave',
#  '~* 8 Ave & W 33 St',
#  '~* W 38 St & 8 Ave',
#  '~* Carmine St & 6 Ave',
#  '~* W 41 St & 8 Ave',
#  '~* 12 Ave & W 40 St',
#  '~* W 18 St & 6 Ave',
#  '~* Greenwich Ave & 8 Ave',
#  '~* Broadway & E 14 St',
#  'E 47 St & Park Ave',
#  'University Pl & E 14 St',
#  '* E 7 St & Avenue A',
#  '~ Cooper Square & E 7 St',
#  '~* South End Ave & Liberty St',
#  'Lafayette St & E 8 St',
#  'Great Jones St',
#  'W 31 St & 7 Ave']

# %%
p = figure(x_range = toptotalnames)
standardize(p)
standardizevbar(p)

x=toptotalnames
top = totals.values
width = 0.85
bottom = 0
p.vbar(x=x,top=top,width=width,bottom=bottom,color='skyblue');

p.title.text = 'Top 20 Stations Used By Subscribers'
p.xaxis.axis_label = 'Station Name'
p.yaxis.axis_label = '# of trips starting or ending'

p.left[0].formatter.use_scientific = False

# %%
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="5465aeb3-eec3-4243-bfc2-97c10014afe3"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("5465aeb3-eec3-4243-bfc2-97c10014afe3");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("5465aeb3-eec3-4243-bfc2-97c10014afe3");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '5465aeb3-eec3-4243-bfc2-97c10014afe3' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"8775c669-3368-4601-8d62-781669f26b4d":{"roots":{"references":[{"attributes":{"below":[{"id":"4e7e1c1f-dbea-476e-aa90-fe80e7452667","type":"CategoricalAxis"}],"left":[{"id":"8e75968f-a240-43da-af9b-fcb1a24d63a8","type":"LinearAxis"}],"renderers":[{"id":"4e7e1c1f-dbea-476e-aa90-fe80e7452667","type":"CategoricalAxis"},{"id":"28547aeb-9129-4bdf-b868-7d911f6a975f","type":"Grid"},{"id":"8e75968f-a240-43da-af9b-fcb1a24d63a8","type":"LinearAxis"},{"id":"66aec9b4-79e8-4e97-9b57-e3448896a7d9","type":"Grid"},{"id":"e8336937-6e04-4c4a-9e98-e8f1e8d2054a","type":"BoxAnnotation"},{"id":"aa1f49bb-f495-40d5-b180-4f3d496f9567","type":"GlyphRenderer"}],"title":{"id":"00fa5b97-99c4-4b99-aaf3-98eb13e87f47","type":"Title"},"toolbar":{"id":"6342de66-30b2-4a23-be91-e783c4bba36b","type":"Toolbar"},"x_range":{"id":"590d3ff5-5695-4d1e-a594-96f484730b29","type":"FactorRange"},"x_scale":{"id":"e0316e0b-04ca-45b3-835d-05c2bc20527c","type":"CategoricalScale"},"y_range":{"id":"8448b418-9c03-41fb-8ea8-1b629aa86c28","type":"DataRange1d"},"y_scale":{"id":"d78f7e65-32cf-473b-89b1-42bc2edd5523","type":"LinearScale"}},"id":"cc2942f8-ffc4-430c-919a-b5eb2b2863ec","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"c8b2c2fd-70c7-4118-886e-b1f7c0c8a56f","type":"BasicTicker"},{"attributes":{"axis_label":"Station Name","axis_label_text_font_size":{"value":"14pt"},"formatter":{"id":"cbbed516-e5f0-472e-bf44-fa6a936a8cfb","type":"CategoricalTickFormatter"},"major_label_orientation":-0.75,"major_label_text_font_size":{"value":"9pt"},"minor_tick_line_color":{"value":null},"plot":{"id":"cc2942f8-ffc4-430c-919a-b5eb2b2863ec","subtype":"Figure","type":"Plot"},"ticker":{"id":"0cd3bb53-cd28-493f-b016-b896b24ee50d","type":"CategoricalTicker"}},"id":"4e7e1c1f-dbea-476e-aa90-fe80e7452667","type":"CategoricalAxis"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"top":{"field":"top"},"width":{"value":0.85},"x":{"field":"x"}},"id":"5f69d744-5660-4aa9-bfc5-abd2844040ef","type":"VBar"},{"attributes":{},"id":"0cd3bb53-cd28-493f-b016-b896b24ee50d","type":"CategoricalTicker"},{"attributes":{},"id":"79f678d8-5d5b-472d-becf-85ff7ce6df7c","type":"WheelZoomTool"},{"attributes":{"source":{"id":"bf48d394-dbdb-49f8-9f5e-bc69dcc9e0bf","type":"ColumnDataSource"}},"id":"7ed7eddd-38f2-4ed6-8ce6-7bf46bd2103e","type":"CDSView"},{"attributes":{"callback":null,"column_names":["x","top"],"data":{"top":{"__ndarray__":"AAAAAMDV3UAAAAAAAHXVQAAAAACAMtVAAAAAAMDy1EAAAAAAQGPUQAAAAAAAS9NAAAAAAEDo0UAAAAAAwFHRQAAAAAAAetBAAAAAAAAQ0EAAAAAAAE/PQAAAAAAAxM5AAAAAAAA+zkAAAAAAAB3OQAAAAAAAlc1AAAAAAAB4zUAAAAAAgBDMQAAAAAAABb5AAAAAAABVvUAAAAAAAGi8QAAAAAAAJrxAAAAAAAAQvEAAAAAAAAi8QA==","dtype":"float64","shape":[23]},"x":["~* Pershing Square North","~* Broadway & E 22 St","~* E 17 St & Broadway","~* West St & Chambers St","~* W 21 St & 6 Ave","~* 8 Ave & W 31 St","~* W 20 St & 11 Ave","~* 8 Ave & W 33 St","~* W 38 St & 8 Ave","~* Carmine St & 6 Ave","~* W 41 St & 8 Ave","~* 12 Ave & W 40 St","~* W 18 St & 6 Ave","~* Greenwich Ave & 8 Ave","~* Broadway & E 14 St","E 47 St & Park Ave","University Pl & E 14 St","* E 7 St & Avenue A","~ Cooper Square & E 7 St","~* South End Ave & Liberty St","Lafayette St & E 8 St","Great Jones St","W 31 St & 7 Ave"]}},"id":"bf48d394-dbdb-49f8-9f5e-bc69dcc9e0bf","type":"ColumnDataSource"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"93aa30c6-f584-4d2e-ac3d-c7f174b218a9","type":"PanTool"},{"id":"79f678d8-5d5b-472d-becf-85ff7ce6df7c","type":"WheelZoomTool"},{"id":"f29b8bbd-e903-47f5-b9cc-8420e71ace7d","type":"BoxZoomTool"},{"id":"8cdf4b9c-4b51-4b5e-937a-79a4111fd296","type":"SaveTool"},{"id":"19db2ee7-7158-47f1-ab75-b8af6a0da6d2","type":"ResetTool"},{"id":"0413cbf4-dfde-4b54-a924-52db4448bab6","type":"HelpTool"}]},"id":"6342de66-30b2-4a23-be91-e783c4bba36b","type":"Toolbar"},{"attributes":{"fill_color":{"valu ...

# %% [markdown]
# #### For customers

# %%
ss = customers.groupby('startstationid').count().max(1).sort_values(ascending=False)[0:20]
se = customers.groupby('endstationid').count().max(1).sort_values(ascending=False)[0:20]

allPoss = np.union1d(ss.index,se.index)
totals = pd.Series(index=allPoss)
for idx,elem in enumerate(allPoss):
    try:
        a = ss.loc[elem]
    except:
        a=0
    try:
        b = se.loc[elem]
    except:
        b=0
    totals.loc[elem] = a+b
totals = totals.sort_values(ascending=False)
print totals.shape
totals
# Out:
# (21L,)
# 2006    8513.0
# 387     7491.0
# 514     6821.0
# 426     6213.0
# 3282    5884.0
# 281     5673.0
# 3165    5267.0
# 3374    4984.0
# 3137    4512.0
# 405     3996.0
# 3256    3954.0
# 217     3954.0
# 2008    3786.0
# 499     3601.0
# 3002    3523.0
# 459     3329.0
# 3143    3166.0
# 3163    3083.0
# 532     2917.0
# 3160    1662.0
# 457     1526.0
# dtype: float64

# %%
toptotalnames = []
for idx,elem in enumerate(totals.index):
    name = data[data.startstationid==elem].startstationname.unique()[0]
    print str(idx+1)+")"+name
    if (np.intersect1d(name,topstartnames).shape[0]!=0 and np.intersect1d(name,topendnames).shape[0]!=0):
        toptotalnames.append('~* ' + name)
    elif np.intersect1d(name,topstartnames).shape[0]!=0:
        toptotalnames.append('~ ' + name)
    elif np.intersect1d(name,topendnames).shape[0]!=0:
        toptotalnames.append('* ' + name)
    else :
        toptotalnames.append(name)
print idx
toptotalnames
# Out:
# 1)Central Park S & 6 Ave
# 2)Centre St & Chambers St
# 3)12 Ave & W 40 St
# 4)West St & Chambers St
# 5)5 Ave & E 88 St
# 6)Grand Army Plaza & Central Park S
# 7)Central Park West & W 72 St
# 8)Central Park North & Adam Clayton Powell Blvd
# 9)5 Ave & E 73 St
# 10)Washington St & Gansevoort St
# 11)Pier 40 - Hudson River Park
# 12)Old Fulton St
# 13)Little West St & 1 Pl
# 14)Broadway & W 60 St
# 15)South End Ave & Liberty St
# 16)W 20 St & 11 Ave
# 17)5 Ave & E 78 St
# 18)Central Park West & W 68 St
# 19)S 5 Pl & S 4 St
# 20)Central Park West & W 76 St
# 21)Broadway & W 58 St
# 20
# ['~* Central Park S & 6 Ave',
#  'Centre St & Chambers St',
#  '~* 12 Ave & W 40 St',
#  '~* West St & Chambers St',
#  '5 Ave & E 88 St',
#  '~ Grand Army Plaza & Central Park S',
#  'Central Park West & W 72 St',
#  'Central Park North & Adam Clayton Powell Blvd',
#  '5 Ave & E 73 St',
#  'Washington St & Gansevoort St',
#  'Pier 40 - Hudson River Park',
#  'Old Fulton St',
#  'Little West St & 1 Pl',
#  'Broadway & W 60 St',
#  '~* South End Ave & Liberty St',
#  '~* W 20 St & 11 Ave',
#  '5 Ave & E 78 St',
#  'Central Park West & W 68 St',
#  'S 5 Pl & S 4 St',
#  'Central Park West & W 76 St',
#  'Broadway & W 58 St']

# %%
p = figure(x_range = toptotalnames)
standardize(p)
standardizevbar(p)

x=toptotalnames
top = totals.values
width = 0.85
bottom = 0
p.vbar(x=x,top=top,width=width,bottom=bottom,color='skyblue');

p.title.text = 'Top 20 Stations Used By Temporary Customers'
p.xaxis.axis_label = 'Station Name'
p.yaxis.axis_label = '# of trips starting or ending'

p.left[0].formatter.use_scientific = False

# %%
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="0d9f02be-5e79-47a8-9a60-c716129eaf38"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("0d9f02be-5e79-47a8-9a60-c716129eaf38");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("0d9f02be-5e79-47a8-9a60-c716129eaf38");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '0d9f02be-5e79-47a8-9a60-c716129eaf38' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"ed9f101e-1948-4d05-87d2-65708e4ca2ff":{"roots":{"references":[{"attributes":{"use_scientific":false},"id":"dd9da858-b886-4ae2-9cf9-38d6860b7468","type":"BasicTickFormatter"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"f91f3760-f201-45ec-921e-3b21568233ea","type":"PanTool"},{"id":"5db3ba20-133d-43fa-833b-9bf3455762c9","type":"WheelZoomTool"},{"id":"a2dc94d8-ebea-46b2-986b-ec0d952e176e","type":"BoxZoomTool"},{"id":"1780d6e6-9263-4533-bbb2-870cbe09dd0a","type":"SaveTool"},{"id":"60e5f79b-8775-4abf-8c67-07ed97361429","type":"ResetTool"},{"id":"6f94075c-6b66-4222-b9d0-4080ee0a85d7","type":"HelpTool"}]},"id":"8a4e7720-56f9-4191-b55e-dbf13699314a","type":"Toolbar"},{"attributes":{"data_source":{"id":"12c48c8a-9321-4dd7-bbcd-1ff9a491571f","type":"ColumnDataSource"},"glyph":{"id":"25f95940-133b-4503-96ac-444f68241e2a","type":"VBar"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"f3cab369-7e97-43cc-b975-53bff1944689","type":"VBar"},"selection_glyph":null,"view":{"id":"750323a3-7c0e-4ba5-8ee8-48331b803f05","type":"CDSView"}},"id":"491e9c59-6d05-48be-ae52-83db8efe77c2","type":"GlyphRenderer"},{"attributes":{},"id":"b3f1ba2c-0db4-41b4-a92a-847358d1de0d","type":"CategoricalTicker"},{"attributes":{"callback":null,"start":0},"id":"81776640-49c5-435f-9c29-8592693ba856","type":"DataRange1d"},{"attributes":{"grid_line_color":{"value":null},"plot":{"id":"edc78141-26fa-4a69-a40b-e6f77fc7ec0c","subtype":"Figure","type":"Plot"},"ticker":{"id":"b3f1ba2c-0db4-41b4-a92a-847358d1de0d","type":"CategoricalTicker"}},"id":"269396ce-d06b-4573-9847-4b3d802cd436","type":"Grid"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"top":{"field":"top"},"width":{"value":0.85},"x":{"field":"x"}},"id":"f3cab369-7e97-43cc-b975-53bff1944689","type":"VBar"},{"attributes":{},"id":"1780d6e6-9263-4533-bbb2-870cbe09dd0a","type":"SaveTool"},{"attributes":{"fill_color":{"value":"skyblue"},"line_color":{"value":"skyblue"},"top":{"field":"top"},"width":{"value":0.85},"x":{"field":"x"}},"id":"25f95940-133b-4503-96ac-444f68241e2a","type":"VBar"},{"attributes":{"align":"center","plot":null,"text":"Top 20 Stations Used By Temporary Customers","text_font_size":{"value":"16pt"}},"id":"56e73ba5-d533-4626-9e44-45b7c9abcf8a","type":"Title"},{"attributes":{"axis_label":"# of trips starting or ending","axis_label_text_font_size":{"value":"14pt"},"formatter":{"id":"dd9da858-b886-4ae2-9cf9-38d6860b7468","type":"BasicTickFormatter"},"major_label_text_font_size":{"value":"9pt"},"plot":{"id":"edc78141-26fa-4a69-a40b-e6f77fc7ec0c","subtype":"Figure","type":"Plot"},"ticker":{"id":"b6154673-1ca7-44b5-8a05-52897aa1effe","type":"BasicTicker"}},"id":"332de6ce-b4d5-43fa-99c8-9b28ef6b1fbe","type":"LinearAxis"},{"attributes":{},"id":"f91f3760-f201-45ec-921e-3b21568233ea","type":"PanTool"},{"attributes":{},"id":"60e5f79b-8775-4abf-8c67-07ed97361429","type":"ResetTool"},{"attributes":{},"id":"6f94075c-6b66-4222-b9d0-4080ee0a85d7","type":"HelpTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"0fc592be-0f47-41e6-91f3-e4895d8a37d1","type":"BoxAnnotation"},{"attributes":{"axis_label":"Station Name","axis_label_text_font_size":{"value":"14pt"},"formatter":{"id":"5293b199-de18-46e9-bbc5-395e8faeebab","type":"CategoricalTickFormatter"},"major_label_orientation":-0.75,"major_label_text_font_size":{"value":"9pt"},"minor_tick_line_color":{"value":null},"plot":{"id":"edc78141-26fa-4a69-a40b-e6f77fc7ec0c","subtype":"Figure","type":"Plot"},"ticker":{"id":"b3f1ba2c-0db4-41b4-a92a-847358d1de0d","type":"CategoricalTicker"}},"id":"c9c0ea8f- ...
